# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('linregrtest.csv')

# %%
df
# Out:
#    year  swine_population  atmospheric_ammonia
# 0  1988              0.38                 0.13
# 1  1989              0.50                 0.21
# 2  1990              0.60                 0.29
# 3  1991              0.75                 0.22
# 4  1992              0.95                 0.19
# 5  1993              1.20                 0.26
# 6  1994              1.40                 0.36
# 7  1995              1.65                 0.37
# 8  1996              1.80                 0.33
# 9  1997              1.85                 0.38

# %%
sns.regplot(x="swine_population", y="atmospheric_ammonia",data=df)
# Out:
# <AxesSubplot:xlabel='swine_population', ylabel='atmospheric_ammonia'>

# %%
sns.regplot(x="atmospheric_ammonia", y="swine_population",data=df)
# Out:
# <AxesSubplot:xlabel='atmospheric_ammonia', ylabel='swine_population'>

# %%
sns.pairplot(df)

# %%
corr_data = df
correlations_matrix = corr_data.corr()
correlations_matrix
# Out:
#                          year  swine_population  atmospheric_ammonia
# year                 1.000000          0.992578             0.851267
# swine_population     0.992578          1.000000             0.850396
# atmospheric_ammonia  0.851267          0.850396             1.000000

# %%
corr_data = df
correlations_matrix = corr_data.corr()
correlations_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_89cba_row0_col0, #T_89cba_row1_col1, #T_89cba_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_89cba_row0_col1, #T_89cba_row1_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_89cba_row0_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_89cba_row1_col2, #T_89cba_row2_col0, #T_89cba_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_89cba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >year</th>
#       <th class="col_heading level0 col1" >swine_population</th>
#       <th class="col_heading level0 col2" >atmospheric_ammonia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89cba_level0_row0" class="row_heading level0 row0" >year</th>
#       <td id="T_89cba_row0_col0" class="data row0 col0" >1.000000</td>
# ...

# %%
sns.heatmap(correlations_matrix, annot=True)
# Out:
# <AxesSubplot:>
