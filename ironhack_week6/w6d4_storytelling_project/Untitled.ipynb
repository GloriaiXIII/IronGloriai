# %%
import pandas as pd
import numpy as np

# %%
dfcovid = pd.read_csv('owid-covid-data.csv')
dfcovid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 135576      ZWE    Africa     Zimbabwe  2021-11-20     133615.0       22.0
# 135577      ZWE    Africa     Zimbabwe  2021-11-21     133647.0       32.0
# 135578      ZWE    Africa     Zimbabwe  2021-11-22     133674.0       27.0
# 135579      ZWE    Africa     Zimbabwe  2021-11-23     133674.0        0.0
# 135580      ZWE    Africa     Zimbabwe  2021-11-24     133747.0       73.0
#
# ...

# %%
df_fb = pd.read_csv('movement-range-2021-11-21.txt',"\t",low_memory=False)
df_fb
# Out:
# D:\Programas\Anaconda\envs\classenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                  ds country polygon_source   polygon_id polygon_name  \
# 0        2021-01-01     AGO           GADM  AGO.10.10_1      Lubango
# 1        2021-01-02     AGO           GADM  AGO.10.10_1      Lubango
# 2        2021-01-03     AGO           GADM  AGO.10.10_1      Lubango
# 3        2021-01-04     AGO           GADM  AGO.10.10_1      Lubango
# 4        2021-01-05     AGO           GADM  AGO.10.10_1      Lubango
# ...             ...     ...            ...          ...          ...
# 4756576  2021-11-17     ZWE           GADM    ZWE.8.3_1       Hwange
# 4756577  2021-04-27     ZWE           GADM    ZWE.9.1_1   Beitbridge
# 4756578  2021-05-20     ZWE           GADM    ZWE.9.1_1   Beitbridge
# ...
