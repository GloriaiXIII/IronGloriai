# %% [markdown]
# # Lab | Computer Vision (a not too serious lab)

# %% [markdown]
# ### Task 1

# %% [markdown]
# In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue. Here is an example if you are not sure what to look for.

# %% [markdown]
# 1.[Coded bias](https://www.netflix.com/title/81328723)
# Documentary available on netflix about artificial intelligence and the bias that is embedded into this technology and how it affects minorities.
#
# This is not an article but a documentary on the subject. It starts from a MediaLab (MIT) project where a woman was carrying out a project with a mirror and artificial intelligence. The mirror was supposed to recognise her face, but in the course of the project she discovered that the programme did not work accurately with black faces. So she started investigating why the facial recognition software works like that and what are they biases and what they meant to society that AI is biased. The train test is done with homogenous samples that mirror society biases.
#
# The documentary also discusses the fact that depending on which technological advances, they are implemented first in the lower social classes, and if in consequence they suppose really advances or not. Consequently the real advantages accrue mainly to the more advantaged classes and on the contrary, the disadvantages of technology, loss of time and control to the less advantaged.
#
# Other covered topic is the fact that there is no legal legislation at all on this issue and where starts and ends individual privacy rights. Finally that algorithms are perceived by society as something objective, but they aren't.

# %% [markdown]
# 2.[How Confucius loses face in China’s new surveillance regime](https://aeon.co/ideas/how-confucius-loses-face-in-chinas-new-surveillance-regime)
#
# The article starts with a definition of 'face' in East Asian societies and its social value. In that societies they have two conceptions: 1.Mianzi that is related with wealth, social status, position, power and prestige and 2.Lian related with moral.
#
# The article focus on how new AI facial recognition systems (Social Credit System) affects the traditional notions of mianzi and lian and moreover with the ethics of AI. With this system all society members are controlled the whole time and it lasts a register and also the fact that is not controlled directly by human members of the government but by autonomous machines.

# %% [markdown]
# -----

# %% [markdown]
# ### Task 2

# %% [markdown]
# 2.Use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done-hint: you will need an image display method, for example

# %%
# %matplotlib inline
from IPython.display import Image
Image('w8d3_lab_image.png')

# %% [markdown]
# *caption: Two giraffes walking on a road with two cars approaching.*

# %% [markdown]
# Although the colours of a giraffe can be perceived, the morphology of the body is amorphous and the neck, the most recognisable part of the giraffe, is non recognisable (does not exist or is the shape that goes downwards?). Moreover, only one shape of the two that should appear is recognised.
#
# The road is imperceptible. There is only grass and vegetation except for a small unnoticed grey patch. While the car is the most accurate form of the elements that should appear, there is only one of the two cars that should appear.
#
# While the image attempts to emulate the input phrase, it is still far from a realistic representation of it.

# %% [markdown]
# -----

# %% [markdown]
# ### Task 3

# %% [markdown]
# 3.Read this [blog article](https://thedatafrog.com/en/articles/dogs-vs-cats/). Link the url to your notebook using the appropriate markdown technique and add a summary into your notebook (as markdown) of any image processing steps you saw the author employ.
