# %% [markdown]
# ## Credentials

# %%
import pandas as pd
import time 

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass
import pprint

# %% [markdown]
# ## GetPass

# %%
client_id = str(getpass.getpass('client_id: '))
client_secret = str(getpass.getpass('client_secret: '))
# Out:
# client_id: ········
# client_secret: ········

# %%
sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id = client_id, client_secret = client_secret))

# %% [markdown]
# ## Get the data from a whole playlist

# %%
# function which handlees more than 100 results

def get_playlist_tracks(user_id,playlist_id):
    results = sp.user_playlist_tracks(user_id,playlist_id)
    tracks=results["items"]
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
results2 = get_playlist_tracks("Klaus Tienaho","3PlzvUAGHzXYS4m5fOkuHP")
results2
# Out:
# [{'added_at': '2010-08-19T21:51:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#       'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#       'id': '5M52tdBnJaKSvOpJGz8mfZ',
#       'name': 'Black Sabbath',
#       'type': 'artist',
#       'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/714ndVxSx8lIWhQxdbcXIs'},
#     'href': 'https://api.spotify.com/v1/albums/714ndVxSx8lIWhQxdbcXIs',
#     'id': '714ndVxSx8lIWhQxdbcXIs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cfa6ec6d5374ce8aec1a73f5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cfa6ec6d5374ce8aec1a73f5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cfa6ec6d5374ce8aec1a73f5',
#       'width': 64}],
#     'name': 'Paranoid',
#     'release_date': '1970-09-18',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:714ndVxSx8lIWhQxdbcXIs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#      'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#      'id': '5M52tdBnJaKSvOpJGz8mfZ',
#      'name': 'Black Sabbath',
#      'type': 'artist',
#      'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 167933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAJE7000057'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3L8WgDYS5TtwbyxOPSAiFf'},
#    'href': 'https://api.spotify.com/v1/tracks/3L8WgDYS5TtwbyxOPSAiFf',
#    'id': '3L8WgDYS5TtwbyxOPSAiFf',
#    'is_local': False,
#    'name': 'Paranoid',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3L8WgDYS5TtwbyxOPSAiFf'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:51:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DFr97A9HnbV3SKTJFu62M'},
#       'href': 'https://api.spotify.com/v1/artists/1DFr97A9HnbV3SKTJFu62M',
#       'id': '1DFr97A9HnbV3SKTJFu62M',
#       'name': 'Motörhead',
#       'type': 'artist',
#       'uri': 'spotify:artist:1DFr97A9HnbV3SKTJFu62M'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/46a9whRz5DF0PC97HrZrqz'},
#     'href': 'https://api.spotify.com/v1/albums/46a9whRz5DF0PC97HrZrqz',
#     'id': '46a9whRz5DF0PC97HrZrqz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dbb4a4384c36fb422b3f070a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dbb4a4384c36fb422b3f070a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dbb4a4384c36fb422b3f070a',
#       'width': 64}],
#     'name': 'Ace Of Spades (Reissue - Expanded Bonus Track Edition)',
#     'release_date': '1980-11-08',
#     'release_date_precision': 'day',
#     'total_tracks': 27,
#     'type': 'album',
#     'uri': 'spotify:album:46a9whRz5DF0PC97HrZrqz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DFr97A9HnbV3SKTJFu62M'},
#      'href': 'https://api.spotify.com/v1/artists/1DFr97A9HnbV3SKTJFu62M',
#      'id': '1DFr97A9HnbV3SKTJFu62M',
#      'name': 'Motörhead',
#      'type': 'artist',
#      'uri': 'spotify:artist:1DFr97A9HnbV3SKTJFu62M'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 166706,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAJE8000033'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/47FyQCd3TYLrZ9TU6MPaWK'},
#    'href': 'https://api.spotify.com/v1/tracks/47FyQCd3TYLrZ9TU6MPaWK',
#    'id': '47FyQCd3TYLrZ9TU6MPaWK',
#    'is_local': False,
#    'name': 'Ace Of Spades',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:47FyQCd3TYLrZ9TU6MPaWK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:51:36Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZLTlhejhndI4Rh53vYhrY'},
#       'href': 'https://api.spotify.com/v1/artists/6ZLTlhejhndI4Rh53vYhrY',
#       'id': '6ZLTlhejhndI4Rh53vYhrY',
#       'name': 'Ozzy Osbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ZLTlhejhndI4Rh53vYhrY'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5FxbYXWhCbyQkUaVzj6hlo'},
#     'href': 'https://api.spotify.com/v1/albums/5FxbYXWhCbyQkUaVzj6hlo',
#     'id': '5FxbYXWhCbyQkUaVzj6hlo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ed5c19fd9206d2d7e73c140c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ed5c19fd9206d2d7e73c140c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ed5c19fd9206d2d7e73c140c',
#       'width': 64}],
#     'name': 'Blizzard Of Ozz',
#     'release_date': '1980-09-20',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5FxbYXWhCbyQkUaVzj6hlo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZLTlhejhndI4Rh53vYhrY'},
#      'href': 'https://api.spotify.com/v1/artists/6ZLTlhejhndI4Rh53vYhrY',
#      'id': '6ZLTlhejhndI4Rh53vYhrY',
#      'name': 'Ozzy Osbourne',
#      'type': 'artist',
#      'uri': 'spotify:artist:6ZLTlhejhndI4Rh53vYhrY'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 290066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10204723'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ao8tE7CIEo3KehDQYYoWv'},
#    'href': 'https://api.spotify.com/v1/tracks/3ao8tE7CIEo3KehDQYYoWv',
#    'id': '3ao8tE7CIEo3KehDQYYoWv',
#    'is_local': False,
#    'name': 'Crazy Train',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3ao8tE7CIEo3KehDQYYoWv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:52:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6q5MEna6Fg46powSoeZJe3'},
#     'href': 'https://api.spotify.com/v1/albums/6q5MEna6Fg46powSoeZJe3',
#     'id': '6q5MEna6Fg46powSoeZJe3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a633718a1d28f157193bd865',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a633718a1d28f157193bd865',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a633718a1d28f157193bd865',
#       'width': 64}],
#     'name': 'The Number Of The Beast (1998 Remastered Edition)',
#     'release_date': '1982',
#     'release_date_precision': 'year',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:6q5MEna6Fg46powSoeZJe3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 291373,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE9801381'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1s4Ie0cT6P73SRSfh3oyGW'},
#    'href': 'https://api.spotify.com/v1/tracks/1s4Ie0cT6P73SRSfh3oyGW',
#    'id': '1s4Ie0cT6P73SRSfh3oyGW',
#    'is_local': False,
#    'name': 'The Number Of The Beast - 1998 Remastered Version',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:1s4Ie0cT6P73SRSfh3oyGW'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:52:34Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#       'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#       'id': '6mdiAmATAx73kdxrNrnlao',
#       'name': 'Iron Maiden',
#       'type': 'artist',
#       'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6q5MEna6Fg46powSoeZJe3'},
#     'href': 'https://api.spotify.com/v1/albums/6q5MEna6Fg46powSoeZJe3',
#     'id': '6q5MEna6Fg46powSoeZJe3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a633718a1d28f157193bd865',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a633718a1d28f157193bd865',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a633718a1d28f157193bd865',
#       'width': 64}],
#     'name': 'The Number Of The Beast (1998 Remastered Edition)',
#     'release_date': '1982',
#     'release_date_precision': 'year',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:6q5MEna6Fg46powSoeZJe3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6mdiAmATAx73kdxrNrnlao'},
#      'href': 'https://api.spotify.com/v1/artists/6mdiAmATAx73kdxrNrnlao',
#      'id': '6mdiAmATAx73kdxrNrnlao',
#      'name': 'Iron Maiden',
#      'type': 'artist',
#      'uri': 'spotify:artist:6mdiAmATAx73kdxrNrnlao'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 432800,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE9801385'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1iGXvUsVVkYBas0Cniw6NB'},
#    'href': 'https://api.spotify.com/v1/tracks/1iGXvUsVVkYBas0Cniw6NB',
#    'id': '1iGXvUsVVkYBas0Cniw6NB',
#    'is_local': False,
#    'name': 'Hallowed Be Thy Name - 1998 Remastered Version',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:1iGXvUsVVkYBas0Cniw6NB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:52:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#       'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#       'id': '5M52tdBnJaKSvOpJGz8mfZ',
#       'name': 'Black Sabbath',
#       'type': 'artist',
#       'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/714ndVxSx8lIWhQxdbcXIs'},
#     'href': 'https://api.spotify.com/v1/albums/714ndVxSx8lIWhQxdbcXIs',
#     'id': '714ndVxSx8lIWhQxdbcXIs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cfa6ec6d5374ce8aec1a73f5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cfa6ec6d5374ce8aec1a73f5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cfa6ec6d5374ce8aec1a73f5',
#       'width': 64}],
#     'name': 'Paranoid',
#     'release_date': '1970-09-18',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:714ndVxSx8lIWhQxdbcXIs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#      'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#      'id': '5M52tdBnJaKSvOpJGz8mfZ',
#      'name': 'Black Sabbath',
#      'type': 'artist',
#      'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 474560,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAJE7000063'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1mnXT8zNssefzrRkeuD8Ov'},
#    'href': 'https://api.spotify.com/v1/tracks/1mnXT8zNssefzrRkeuD8Ov',
#    'id': '1mnXT8zNssefzrRkeuD8Ov',
#    'is_local': False,
#    'name': 'War Pigs',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1mnXT8zNssefzrRkeuD8Ov'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:53:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#       'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#       'id': '711MCceyCBcFnzjGY4Q7Un',
#       'name': 'AC/DC',
#       'type': 'artist',
#       'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/19QZHLQTSVlL8jPbPxb709'},
#     'href': 'https://api.spotify.com/v1/albums/19QZHLQTSVlL8jPbPxb709',
#     'id': '19QZHLQTSVlL8jPbPxb709',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731d3cfbea013f3dd590cfd735',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021d3cfbea013f3dd590cfd735',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511d3cfbea013f3dd590cfd735',
#       'width': 64}],
#     'name': 'Back In Black',
#     'release_date': '1980-07-25',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:19QZHLQTSVlL8jPbPxb709'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#      'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#      'id': '711MCceyCBcFnzjGY4Q7Un',
#      'name': 'AC/DC',
#      'type': 'artist',
#      'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 255200,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUAP08000046'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6SPOlvJok6QmNWkvUVPQMs'},
#    'href': 'https://api.spotify.com/v1/tracks/6SPOlvJok6QmNWkvUVPQMs',
#    'id': '6SPOlvJok6QmNWkvUVPQMs',
#    'is_local': False,
#    'name': 'Back In Black',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:6SPOlvJok6QmNWkvUVPQMs'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:54:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#       'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#       'id': '5M52tdBnJaKSvOpJGz8mfZ',
#       'name': 'Black Sabbath',
#       'type': 'artist',
#       'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/714ndVxSx8lIWhQxdbcXIs'},
#     'href': 'https://api.spotify.com/v1/albums/714ndVxSx8lIWhQxdbcXIs',
#     'id': '714ndVxSx8lIWhQxdbcXIs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cfa6ec6d5374ce8aec1a73f5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cfa6ec6d5374ce8aec1a73f5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cfa6ec6d5374ce8aec1a73f5',
#       'width': 64}],
#     'name': 'Paranoid',
#     'release_date': '1970-09-18',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:714ndVxSx8lIWhQxdbcXIs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#      'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#      'id': '5M52tdBnJaKSvOpJGz8mfZ',
#      'name': 'Black Sabbath',
#      'type': 'artist',
#      'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 354240,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAJE7000085'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5TFyNdCLlC1ZRuwczqaS97'},
#    'href': 'https://api.spotify.com/v1/tracks/5TFyNdCLlC1ZRuwczqaS97',
#    'id': '5TFyNdCLlC1ZRuwczqaS97',
#    'is_local': False,
#    'name': 'Iron Man',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5TFyNdCLlC1ZRuwczqaS97'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:54:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#       'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#       'id': '5M52tdBnJaKSvOpJGz8mfZ',
#       'name': 'Black Sabbath',
#       'type': 'artist',
#       'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2xlljcaxcJxmnGO4xJq7YZ'},
#     'href': 'https://api.spotify.com/v1/albums/2xlljcaxcJxmnGO4xJq7YZ',
#     'id': '2xlljcaxcJxmnGO4xJq7YZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a6c7686870e2761c038958ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a6c7686870e2761c038958ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a6c7686870e2761c038958ca',
#       'width': 64}],
#     'name': 'Heaven And Hell',
#     'release_date': '1980-04-25',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:2xlljcaxcJxmnGO4xJq7YZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#      'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#      'id': '5M52tdBnJaKSvOpJGz8mfZ',
#      'name': 'Black Sabbath',
#      'type': 'artist',
#      'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 417600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM70900392'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6O6mF9dYWqJrvS6eWs5iIp'},
#    'href': 'https://api.spotify.com/v1/tracks/6O6mF9dYWqJrvS6eWs5iIp',
#    'id': '6O6mF9dYWqJrvS6eWs5iIp',
#    'is_local': False,
#    'name': 'Heaven And Hell',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6O6mF9dYWqJrvS6eWs5iIp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:54:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klaust'},
#    'href': 'https://api.spotify.com/v1/users/klaust',
#    'id': 'klaust',
#    'type': 'user',
#    'uri': 'spotify:user:klaust'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tRsMl4eGxwoNabM08Dm4I'},
#       'href': 'https://api.spotify.com/v1/artists/2tRsMl4eGxwoNabM08Dm4I',
#       'id': '2tRsMl4eGxwoNabM08Dm4I',
#       'name': 'Judas Priest',
#       'type': 'artist',
#       'uri': 'spotify:artist:2tRsMl4eGxwoNabM08Dm4I'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7LgrhuKnAXpNEv8qzcVd2t'},
#     'href': 'https://api.spotify.com/v1/albums/7LgrhuKnAXpNEv8qzcVd2t',
#     'id': '7LgrhuKnAXpNEv8qzcVd2t',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27360db4ca924d17bc6754e89aa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0260db4ca924d17bc6754e89aa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485160db4ca924d17bc6754e89aa',
#       'width': 64}],
#     'name': 'Painkiller',
#     'release_date': '1990-09-26',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:7LgrhuKnAXpNEv8qzcVd2t'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tRsMl4eGxwoNabM08Dm4I'},
#      'href': 'https://api.spotify.com/v1/artists/2tRsMl4eGxwoNabM08Dm4I',
#      'id': '2tRsMl4eGxwoNabM08Dm4I',
#      'name': 'Judas Priest',
#      'type': 'artist',
#      'uri': 'spotify:artist:2tRsMl4eGxwoNabM08Dm4I'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 365826,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBBN0102557'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0L7zm6afBEtrNKo6C6Gj08'},
#    'href': 'https://api.spotify.com/v1/tracks/0L7zm6afBEtrNKo6C6Gj08',
#    'id': '0L7zm6afBEtrNKo6C6Gj08',
#    'is_local': False,
#    'name': 'Painkiller',
#    'popularity': 65,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e42a4de803594215aa4d244895f8d2abb1367697?cid=975acdb96dda4d689223d4fedf173212',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0L7zm6afBEtrNKo6C6Gj08'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:56:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/568ZhdwyaiCyOGJRtNYhWf'},
#       'href': 'https://api.spotify.com/v1/artists/568ZhdwyaiCyOGJRtNYhWf',
#       'id': '568ZhdwyaiCyOGJRtNYhWf',
#       'name': 'Deep Purple',
#       'type': 'artist',
#       'uri': 'spotify:artist:568ZhdwyaiCyOGJRtNYhWf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2jm9Vixt3Nn2oE4VtOVUD8'},
#     'href': 'https://api.spotify.com/v1/albums/2jm9Vixt3Nn2oE4VtOVUD8',
#     'id': '2jm9Vixt3Nn2oE4VtOVUD8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27325b36a6170824fefd38d337e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0225b36a6170824fefd38d337e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485125b36a6170824fefd38d337e',
#       'width': 64}],
#     'name': 'Deepest Purple: The Very Best of Deep Purple',
#     'release_date': '1980',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2jm9Vixt3Nn2oE4VtOVUD8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/568ZhdwyaiCyOGJRtNYhWf'},
#      'href': 'https://api.spotify.com/v1/artists/568ZhdwyaiCyOGJRtNYhWf',
#      'id': '568ZhdwyaiCyOGJRtNYhWf',
#      'name': 'Deep Purple',
#      'type': 'artist',
#      'uri': 'spotify:artist:568ZhdwyaiCyOGJRtNYhWf'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 367946,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBDXG0600146'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/79q7xFOodcfIVbpNHjE2gB'},
#    'href': 'https://api.spotify.com/v1/tracks/79q7xFOodcfIVbpNHjE2gB',
#    'id': '79q7xFOodcfIVbpNHjE2gB',
#    'is_local': False,
#    'name': 'Highway Star',
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/027c0a9ef8e8526f84a7b7bf53aed96bcd05ed53?cid=975acdb96dda4d689223d4fedf173212',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:79q7xFOodcfIVbpNHjE2gB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:57:10Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#       'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#       'id': '5M52tdBnJaKSvOpJGz8mfZ',
#       'name': 'Black Sabbath',
#       'type': 'artist',
#       'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0hA1dvEDnXYHiSYfL0tlmV'},
#     'href': 'https://api.spotify.com/v1/albums/0hA1dvEDnXYHiSYfL0tlmV',
#     'id': '0hA1dvEDnXYHiSYfL0tlmV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c8ffd97df27b3cecd416121c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c8ffd97df27b3cecd416121c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c8ffd97df27b3cecd416121c',
#       'width': 64}],
#     'name': 'Black Sabbath',
#     'release_date': '1970-02-13',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:0hA1dvEDnXYHiSYfL0tlmV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5M52tdBnJaKSvOpJGz8mfZ'},
#      'href': 'https://api.spotify.com/v1/artists/5M52tdBnJaKSvOpJGz8mfZ',
#      'id': '5M52tdBnJaKSvOpJGz8mfZ',
#      'name': 'Black Sabbath',
#      'type': 'artist',
#      'uri': 'spotify:artist:5M52tdBnJaKSvOpJGz8mfZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 379733,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAJE7000076'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2rBPcEtQsxplAJadn8E3uR'},
#    'href': 'https://api.spotify.com/v1/tracks/2rBPcEtQsxplAJadn8E3uR',
#    'id': '2rBPcEtQsxplAJadn8E3uR',
#    'is_local': False,
#    'name': 'Black Sabbath',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2rBPcEtQsxplAJadn8E3uR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:57:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Yox196W7bzVNZI7RBaPnf'},
#       'href': 'https://api.spotify.com/v1/artists/1Yox196W7bzVNZI7RBaPnf',
#       'id': '1Yox196W7bzVNZI7RBaPnf',
#       'name': 'Megadeth',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Yox196W7bzVNZI7RBaPnf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0qaLL09EtF1hiUis7PRvaJ'},
#     'href': 'https://api.spotify.com/v1/albums/0qaLL09EtF1hiUis7PRvaJ',
#     'id': '0qaLL09EtF1hiUis7PRvaJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273be9fa5a89479b6af481938a0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02be9fa5a89479b6af481938a0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851be9fa5a89479b6af481938a0',
#       'width': 64}],
#     'name': 'Rust In Peace (Expanded Edition)',
#     'release_date': '1990-10-04',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:0qaLL09EtF1hiUis7PRvaJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Yox196W7bzVNZI7RBaPnf'},
#      'href': 'https://api.spotify.com/v1/artists/1Yox196W7bzVNZI7RBaPnf',
#      'id': '1Yox196W7bzVNZI7RBaPnf',
#      'name': 'Megadeth',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Yox196W7bzVNZI7RBaPnf'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 392600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA20400647'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5LyRtsQLhcXmy50VXhQXXS'},
#    'href': 'https://api.spotify.com/v1/tracks/5LyRtsQLhcXmy50VXhQXXS',
#    'id': '5LyRtsQLhcXmy50VXhQXXS',
#    'is_local': False,
#    'name': 'Holy Wars...The Punishment Due - Remastered',
#    'popularity': 67,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5LyRtsQLhcXmy50VXhQXXS'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:57:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tRsMl4eGxwoNabM08Dm4I'},
#       'href': 'https://api.spotify.com/v1/artists/2tRsMl4eGxwoNabM08Dm4I',
#       'id': '2tRsMl4eGxwoNabM08Dm4I',
#       'name': 'Judas Priest',
#       'type': 'artist',
#       'uri': 'spotify:artist:2tRsMl4eGxwoNabM08Dm4I'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5k3WFIHmmuHrUWSj5McaAe'},
#     'href': 'https://api.spotify.com/v1/albums/5k3WFIHmmuHrUWSj5McaAe',
#     'id': '5k3WFIHmmuHrUWSj5McaAe',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735319553a5a4c482208a17368',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025319553a5a4c482208a17368',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515319553a5a4c482208a17368',
#       'width': 64}],
#     'name': 'Sad Wings Of Destiny',
#     'release_date': '1976',
#     'release_date_precision': 'year',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:5k3WFIHmmuHrUWSj5McaAe'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tRsMl4eGxwoNabM08Dm4I'},
#      'href': 'https://api.spotify.com/v1/artists/2tRsMl4eGxwoNabM08Dm4I',
#      'id': '2tRsMl4eGxwoNabM08Dm4I',
#      'name': 'Judas Priest',
#      'type': 'artist',
#      'uri': 'spotify:artist:2tRsMl4eGxwoNabM08Dm4I'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 473560,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USKO10501189'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2B3LrkMAmRVFj6RORrDLHi'},
#    'href': 'https://api.spotify.com/v1/tracks/2B3LrkMAmRVFj6RORrDLHi',
#    'id': '2B3LrkMAmRVFj6RORrDLHi',
#    'is_local': False,
#    'name': 'Victim Of Changes',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2B3LrkMAmRVFj6RORrDLHi'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2010-08-19T21:57:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tRsMl4eGxwoNabM08Dm4I'},
#       'href': 'https://api.spotify.com/v1/artists/2tRsMl4eGxwoNabM08Dm4I',
#       'id': '2tRsMl4eGxwoNabM08Dm4I',
#       'name': 'Judas Priest',
#       'type': 'artist',
#       'uri': 'spotify:artist:2tRsMl4eGxwoNabM08Dm4I'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0V7mTTzioHiYIjfM8ATZBI'},
#     'href': 'https://api.spotify.com/v1/albums/0V7mTTzioHiYIjfM8ATZBI',
#     'id': '0V7mTTzioHiYIjfM8ATZBI',
# ...
#    'href': 'https://api.spotify.com/v1/users/klaust',
#    'id': 'klaust',
#    'type': 'user',
#    'uri': 'spotify:user:klaust'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MZ8NERIuOS610KBhr6yna'},
#       'href': 'https://api.spotify.com/v1/artists/1MZ8NERIuOS610KBhr6yna',
#       'id': '1MZ8NERIuOS610KBhr6yna',
#       'name': 'Tygers Of Pan Tang',
#       'type': 'artist',
#       'uri': 'spotify:artist:1MZ8NERIuOS610KBhr6yna'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0MBqeOdVoHfhwRf7LjsWy2'},
#     'href': 'https://api.spotify.com/v1/albums/0MBqeOdVoHfhwRf7LjsWy2',
#     'id': '0MBqeOdVoHfhwRf7LjsWy2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27315f46409cd6e13532a1a551e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0215f46409cd6e13532a1a551e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485115f46409cd6e13532a1a551e',
#       'width': 64}],
#     'name': 'Spellbound',
#     'release_date': '1981-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:0MBqeOdVoHfhwRf7LjsWy2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1MZ8NERIuOS610KBhr6yna'},
#      'href': 'https://api.spotify.com/v1/artists/1MZ8NERIuOS610KBhr6yna',
#      'id': '1MZ8NERIuOS610KBhr6yna',
#      'name': 'Tygers Of Pan Tang',
#      'type': 'artist',
#      'uri': 'spotify:artist:1MZ8NERIuOS610KBhr6yna'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 220626,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70970029'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1alav0oB46PY36eKNN6e3X'},
#    'href': 'https://api.spotify.com/v1/tracks/1alav0oB46PY36eKNN6e3X',
#    'id': '1alav0oB46PY36eKNN6e3X',
#    'is_local': False,
#    'name': 'Gangland',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1alav0oB46PY36eKNN6e3X'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-21T21:57:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klaust'},
#    'href': 'https://api.spotify.com/v1/users/klaust',
#    'id': 'klaust',
#    'type': 'user',
#    'uri': 'spotify:user:klaust'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28hJdGN1Awf7u3ifk2lVkg'},
#       'href': 'https://api.spotify.com/v1/artists/28hJdGN1Awf7u3ifk2lVkg',
#       'id': '28hJdGN1Awf7u3ifk2lVkg',
#       'name': 'Testament',
#       'type': 'artist',
#       'uri': 'spotify:artist:28hJdGN1Awf7u3ifk2lVkg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1i0xUSNR8hWBIeaDSnN569'},
#     'href': 'https://api.spotify.com/v1/albums/1i0xUSNR8hWBIeaDSnN569',
#     'id': '1i0xUSNR8hWBIeaDSnN569',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27391b5e0a20d45f2b9227f656d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0291b5e0a20d45f2b9227f656d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485191b5e0a20d45f2b9227f656d',
#       'width': 64}],
#     'name': 'The New Order',
#     'release_date': '1988-04-26',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1i0xUSNR8hWBIeaDSnN569'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28hJdGN1Awf7u3ifk2lVkg'},
#      'href': 'https://api.spotify.com/v1/artists/28hJdGN1Awf7u3ifk2lVkg',
#      'id': '28hJdGN1Awf7u3ifk2lVkg',
#      'name': 'Testament',
#      'type': 'artist',
#      'uri': 'spotify:artist:28hJdGN1Awf7u3ifk2lVkg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 255360,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT20001115'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4NKqJMlONXzac3DEmh5iwp'},
#    'href': 'https://api.spotify.com/v1/tracks/4NKqJMlONXzac3DEmh5iwp',
#    'id': '4NKqJMlONXzac3DEmh5iwp',
#    'is_local': False,
#    'name': 'Trial by Fire',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/585aa66d14ccb03a9ddf044a236224ff9905faf2?cid=975acdb96dda4d689223d4fedf173212',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4NKqJMlONXzac3DEmh5iwp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-21T21:58:33Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klaust'},
#    'href': 'https://api.spotify.com/v1/users/klaust',
#    'id': 'klaust',
#    'type': 'user',
#    'uri': 'spotify:user:klaust'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#       'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#       'id': '2ye2Wgw4gimLv2eAKyk1NB',
#       'name': 'Metallica',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}],
#     'available_markets': ['CA', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0vNBQof86Lv5gLuf26ML7o'},
#     'href': 'https://api.spotify.com/v1/albums/0vNBQof86Lv5gLuf26ML7o',
#     'id': '0vNBQof86Lv5gLuf26ML7o',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27320292e6cce666a69ba5a86fb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0220292e6cce666a69ba5a86fb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485120292e6cce666a69ba5a86fb',
#       'width': 64}],
#     'name': "Kill 'Em All (Remastered)",
#     'release_date': '1983-07-25',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:0vNBQof86Lv5gLuf26ML7o'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#      'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#      'id': '2ye2Wgw4gimLv2eAKyk1NB',
#      'name': 'Metallica',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}],
#    'available_markets': ['CA', 'US'],
#    'disc_number': 1,
#    'duration_ms': 248546,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USEE19900916'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4k1IS2uF2dGcU3GzOOZqqb'},
#    'href': 'https://api.spotify.com/v1/tracks/4k1IS2uF2dGcU3GzOOZqqb',
#    'id': '4k1IS2uF2dGcU3GzOOZqqb',
#    'is_local': False,
#    'name': 'Whiplash (Remastered)',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5a458999949126a4ef4e392b4aaeb0f4bf990d20?cid=975acdb96dda4d689223d4fedf173212',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:4k1IS2uF2dGcU3GzOOZqqb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-02-06T15:56:28Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klaust'},
#    'href': 'https://api.spotify.com/v1/users/klaust',
#    'id': 'klaust',
#    'type': 'user',
#    'uri': 'spotify:user:klaust'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6H1RjVyNruCmrBEWRbD0VZ'},
#       'href': 'https://api.spotify.com/v1/artists/6H1RjVyNruCmrBEWRbD0VZ',
#       'id': '6H1RjVyNruCmrBEWRbD0VZ',
#       'name': 'Def Leppard',
#       'type': 'artist',
#       'uri': 'spotify:artist:6H1RjVyNruCmrBEWRbD0VZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/53YdXbilJgJV6u5S6g3BUf'},
#     'href': 'https://api.spotify.com/v1/albums/53YdXbilJgJV6u5S6g3BUf',
#     'id': '53YdXbilJgJV6u5S6g3BUf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f850966143ee9990e5849c76',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f850966143ee9990e5849c76',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f850966143ee9990e5849c76',
#       'width': 64}],
#     'name': 'Pyromania',
#     'release_date': '1983-01-20',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:53YdXbilJgJV6u5S6g3BUf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6H1RjVyNruCmrBEWRbD0VZ'},
#      'href': 'https://api.spotify.com/v1/artists/6H1RjVyNruCmrBEWRbD0VZ',
#      'id': '6H1RjVyNruCmrBEWRbD0VZ',
#      'name': 'Def Leppard',
#      'type': 'artist',
#      'uri': 'spotify:artist:6H1RjVyNruCmrBEWRbD0VZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 247828,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBF088200420'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/06VOoCjZ6OfCbOKVIhCIT9'},
#    'href': 'https://api.spotify.com/v1/tracks/06VOoCjZ6OfCbOKVIhCIT9',
#    'id': '06VOoCjZ6OfCbOKVIhCIT9',
#    'is_local': False,
#    'name': 'Rock Of Ages',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:06VOoCjZ6OfCbOKVIhCIT9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-02-06T15:56:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/klaust'},
#    'href': 'https://api.spotify.com/v1/users/klaust',
#    'id': 'klaust',
#    'type': 'user',
#    'uri': 'spotify:user:klaust'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6H1RjVyNruCmrBEWRbD0VZ'},
#       'href': 'https://api.spotify.com/v1/artists/6H1RjVyNruCmrBEWRbD0VZ',
#       'id': '6H1RjVyNruCmrBEWRbD0VZ',
#       'name': 'Def Leppard',
#       'type': 'artist',
#       'uri': 'spotify:artist:6H1RjVyNruCmrBEWRbD0VZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/53YdXbilJgJV6u5S6g3BUf'},
#     'href': 'https://api.spotify.com/v1/albums/53YdXbilJgJV6u5S6g3BUf',
#     'id': '53YdXbilJgJV6u5S6g3BUf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f850966143ee9990e5849c76',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f850966143ee9990e5849c76',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f850966143ee9990e5849c76',
#       'width': 64}],
#     'name': 'Pyromania',
#     'release_date': '1983-01-20',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:53YdXbilJgJV6u5S6g3BUf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6H1RjVyNruCmrBEWRbD0VZ'},
#      'href': 'https://api.spotify.com/v1/artists/6H1RjVyNruCmrBEWRbD0VZ',
#      'id': '6H1RjVyNruCmrBEWRbD0VZ',
#      'name': 'Def Leppard',
#      'type': 'artist',
#      'uri': 'spotify:artist:6H1RjVyNruCmrBEWRbD0VZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 247962,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBF088300067'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5jF3jBoctZU17gY0FFYpVE'},
#    'href': 'https://api.spotify.com/v1/tracks/5jF3jBoctZU17gY0FFYpVE',
#    'id': '5jF3jBoctZU17gY0FFYpVE',
#    'is_local': False,
#    'name': 'Photograph',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:5jF3jBoctZU17gY0FFYpVE'},
#   'video_thumbnail': {'url': None}}]

# %%
len(results2)
# Out:
# 497

# %% [markdown]
# ## Iterate over the tracks of a playlist to collect the song name, song URI/ID and the artist

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results2

for r in results2:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf2 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf2['song_name'] = songdf2['song_name'].str.lower()
songdf2['artist'] = songdf2['artist'].str.lower()
songdf2
# Out:
#                                              song_name  \
# 0                                             paranoid
# 1                                        ace of spades
# 2                                          crazy train
# 3    the number of the beast - 1998 remastered version
# 4       hallowed be thy name - 1998 remastered version
# ..                                                 ...
# 492                                           gangland
# 493                                      trial by fire
# 494                              whiplash (remastered)
# 495                                       rock of ages
# 496                                         photograph
#
#                     song_id              artist
# 0    3L8WgDYS5TtwbyxOPSAiFf       black sabbath
# 1    47FyQCd3TYLrZ9TU6MPaWK           motörhead
# 2    3ao8tE7CIEo3KehDQYYoWv       ozzy osbourne
# 3    1s4Ie0cT6P73SRSfh3oyGW         iron maiden
# 4    1iGXvUsVVkYBas0Cniw6NB         iron maiden
# ..                      ...                 ...
# 492  1alav0oB46PY36eKNN6e3X  tygers of pan tang
# 493  4NKqJMlONXzac3DEmh5iwp           testament
# 494  4k1IS2uF2dGcU3GzOOZqqb           metallica
# 495  06VOoCjZ6OfCbOKVIhCIT9         def leppard
# 496  5jF3jBoctZU17gY0FFYpVE         def leppard
#
# [497 rows x 3 columns]

# %% [markdown]
# ## Get the audio features

# %%
feats=sp.audio_features(tracks=song_id[0:99])

# %%
feats[0].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
audio_feat_df1=pd.DataFrame(sp.audio_features(tracks=song_id[0:100]))
audio_feat_df2=pd.DataFrame(sp.audio_features(tracks=song_id[100:200]))
audio_feat_df3=pd.DataFrame(sp.audio_features(tracks=song_id[200:300]))
audio_feat_df4=pd.DataFrame(sp.audio_features(tracks=song_id[300:400]))
audio_feat_df5=pd.DataFrame(sp.audio_features(tracks=song_id[400:500]))

# %%
audio_feat_df3
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.311   0.806    4   -12.337     1       0.0499      0.091900
# 1          0.478   0.937    0    -6.173     0       0.1060      0.007710
# 2          0.475   0.576    9   -13.059     1       0.0312      0.021800
# 3          0.448   0.833    6    -8.582     1       0.0432      0.004270
# 4          0.457   0.779    7    -6.323     1       0.2570      0.018500
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.416   0.792    6   -11.885     1       0.0604      0.003520
# 96         0.397   0.969    9    -3.892     1       0.0463      0.000002
# 97         0.346   0.765    8    -8.558     1       0.0413      0.002290
# 98         0.493   0.938    4    -7.221     0       0.0819      0.000023
# 99         0.158   0.973    4    -4.000     0       0.2130      0.000843
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.003670    0.1410   0.0772  135.121  audio_features
# 1           0.018100    0.8400   0.2940  131.418  audio_features
# 2           0.022100    0.3910   0.5240   96.378  audio_features
# 3           0.000703    0.2310   0.5920  116.676  audio_features
# 4           0.000002    0.0247   0.7340   86.573  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.105000    0.4020   0.5200  104.708  audio_features
# 96          0.517000    0.0513   0.7020  134.288  audio_features
# 97          0.000008    0.2130   0.6440  106.463  audio_features
# 98          0.015900    0.1210   0.7070   94.655  audio_features
# 99          0.742000    0.0938   0.1370  167.167  audio_features
#
#                         id                                   uri  \
# 0   1n5tv95U5Ixc9kEki1C5MA  spotify:track:1n5tv95U5Ixc9kEki1C5MA
# 1   1EORu8Coheibl21VjHtbRg  spotify:track:1EORu8Coheibl21VjHtbRg
# 2   25suYHVUwWFTG6G31kuhZH  spotify:track:25suYHVUwWFTG6G31kuhZH
# 3   2VVat48YTOk3wALkMjNxvQ  spotify:track:2VVat48YTOk3wALkMjNxvQ
# 4   0N4NO2BmOIBWrCQ9r8Ei8m  spotify:track:0N4NO2BmOIBWrCQ9r8Ei8m
# ..                     ...                                   ...
# 95  1bWe6OdgzmJrXLsJN2HDXx  spotify:track:1bWe6OdgzmJrXLsJN2HDXx
# 96  2nWjhmRImt6LScZIPQMBnM  spotify:track:2nWjhmRImt6LScZIPQMBnM
# 97  3G0EKJZy0j3rMG077UawaC  spotify:track:3G0EKJZy0j3rMG077UawaC
# 98  1Iw3wchVrb4rahrtYqcdW6  spotify:track:1Iw3wchVrb4rahrtYqcdW6
# 99  0J58LxQpWoigdtTDXrKnX0  spotify:track:0J58LxQpWoigdtTDXrKnX0
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/1n5tv95U5Ixc...
# 1   https://api.spotify.com/v1/tracks/1EORu8Coheib...
# 2   https://api.spotify.com/v1/tracks/25suYHVUwWFT...
# 3   https://api.spotify.com/v1/tracks/2VVat48YTOk3...
# 4   https://api.spotify.com/v1/tracks/0N4NO2BmOIBW...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/1bWe6OdgzmJr...
# 96  https://api.spotify.com/v1/tracks/2nWjhmRImt6L...
# 97  https://api.spotify.com/v1/tracks/3G0EKJZy0j3r...
# 98  https://api.spotify.com/v1/tracks/1Iw3wchVrb4r...
# 99  https://api.spotify.com/v1/tracks/0J58LxQpWoig...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/1n5t...       639867
# 1   https://api.spotify.com/v1/audio-analysis/1EOR...       298401
# 2   https://api.spotify.com/v1/audio-analysis/25su...       397773
# 3   https://api.spotify.com/v1/audio-analysis/2VVa...       327400
# 4   https://api.spotify.com/v1/audio-analysis/0N4N...       313667
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/1bWe...       211733
# 96  https://api.spotify.com/v1/audio-analysis/2nWj...       218293
# 97  https://api.spotify.com/v1/audio-analysis/3G0E...       284427
# 98  https://api.spotify.com/v1/audio-analysis/1Iw3...       146173
# 99  https://api.spotify.com/v1/audio-analysis/0J58...       451533
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
frames = [audio_feat_df1, audio_feat_df2,audio_feat_df3, audio_feat_df4,audio_feat_df5]
result = pd.concat(frames)
result.reset_index(drop=True, inplace=True)
result
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.418   0.668    6   -11.297     0       0.0820      0.000143
# 1           0.324   0.991    6    -4.465     1       0.1970      0.002470
# 2           0.473   0.918    9    -3.580     1       0.0566      0.014500
# 3           0.420   0.930    2    -5.583     0       0.0638      0.018900
# 4           0.304   0.909    9    -5.162     1       0.0362      0.001850
# ..            ...     ...  ...       ...   ...          ...           ...
# 492         0.297   0.991    7    -2.365     1       0.2430      0.000106
# 493         0.331   0.791    1   -11.187     1       0.0425      0.000257
# 494         0.386   0.911    4    -6.474     0       0.0956      0.000608
# 495         0.710   0.806   11    -7.660     0       0.0447      0.009470
# 496         0.600   0.873    4    -6.542     1       0.0507      0.000354
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0             0.00113    0.1730    0.379  162.663  audio_features
# 1             0.00895    0.1040    0.195  140.245  audio_features
# 2             0.00248    0.3270    0.586  137.606  audio_features
# 3             0.00675    0.2640    0.344   99.641  audio_features
# 4             0.12200    0.3620    0.348  103.990  audio_features
# ..                ...       ...      ...      ...             ...
# 492           0.00122    0.2730    0.189  116.428  audio_features
# 493           0.42600    0.2100    0.309   94.907  audio_features
# 494           0.44300    0.1350    0.188  158.045  audio_features
# 495           0.08950    0.1800    0.621  105.866  audio_features
# 496           0.42700    0.0604    0.632  123.676  audio_features
#
#                          id                                   uri  \
# 0    3L8WgDYS5TtwbyxOPSAiFf  spotify:track:3L8WgDYS5TtwbyxOPSAiFf
# 1    47FyQCd3TYLrZ9TU6MPaWK  spotify:track:47FyQCd3TYLrZ9TU6MPaWK
# 2    3ao8tE7CIEo3KehDQYYoWv  spotify:track:3ao8tE7CIEo3KehDQYYoWv
# 3    1s4Ie0cT6P73SRSfh3oyGW  spotify:track:1s4Ie0cT6P73SRSfh3oyGW
# 4    1iGXvUsVVkYBas0Cniw6NB  spotify:track:1iGXvUsVVkYBas0Cniw6NB
# ..                      ...                                   ...
# 492  1alav0oB46PY36eKNN6e3X  spotify:track:1alav0oB46PY36eKNN6e3X
# 493  4NKqJMlONXzac3DEmh5iwp  spotify:track:4NKqJMlONXzac3DEmh5iwp
# 494  4k1IS2uF2dGcU3GzOOZqqb  spotify:track:4k1IS2uF2dGcU3GzOOZqqb
# 495  06VOoCjZ6OfCbOKVIhCIT9  spotify:track:06VOoCjZ6OfCbOKVIhCIT9
# 496  5jF3jBoctZU17gY0FFYpVE  spotify:track:5jF3jBoctZU17gY0FFYpVE
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/3L8WgDYS5Ttw...
# 1    https://api.spotify.com/v1/tracks/47FyQCd3TYLr...
# 2    https://api.spotify.com/v1/tracks/3ao8tE7CIEo3...
# 3    https://api.spotify.com/v1/tracks/1s4Ie0cT6P73...
# 4    https://api.spotify.com/v1/tracks/1iGXvUsVVkYB...
# ..                                                 ...
# 492  https://api.spotify.com/v1/tracks/1alav0oB46PY...
# 493  https://api.spotify.com/v1/tracks/4NKqJMlONXza...
# 494  https://api.spotify.com/v1/tracks/4k1IS2uF2dGc...
# 495  https://api.spotify.com/v1/tracks/06VOoCjZ6OfC...
# 496  https://api.spotify.com/v1/tracks/5jF3jBoctZU1...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/3L8W...       167933
# 1    https://api.spotify.com/v1/audio-analysis/47Fy...       166707
# 2    https://api.spotify.com/v1/audio-analysis/3ao8...       290067
# 3    https://api.spotify.com/v1/audio-analysis/1s4I...       291373
# 4    https://api.spotify.com/v1/audio-analysis/1iGX...       432800
# ..                                                 ...          ...
# 492  https://api.spotify.com/v1/audio-analysis/1ala...       220627
# 493  https://api.spotify.com/v1/audio-analysis/4NKq...       255360
# 494  https://api.spotify.com/v1/audio-analysis/4k1I...       248547
# 495  https://api.spotify.com/v1/audio-analysis/06VO...       247829
# 496  https://api.spotify.com/v1/audio-analysis/5jF3...       247962
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 492               4
# 493               4
# 494               4
# 495               4
# 496               4
#
# [497 rows x 18 columns]

# %% [markdown]
# ## Add more songs

# %% [markdown]
# - [80s Heavy Metal](https://open.spotify.com/playlist/7bcOsrWwa5jASp5zwr6RXD)
# - by Kjetil Myhre
# - 106 songs

# %%
results3 = get_playlist_tracks("Kjetil Myhre","7bcOsrWwa5jASp5zwr6RXD")
len(results3)
# Out:
# 106

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results3

for r in results3:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf3 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf3['song_name'] = songdf3['song_name'].str.lower()
songdf3['artist'] = songdf3['artist'].str.lower()
songdf3
# Out:
#                    song_name                 song_id          artist
# 0        rainbow in the dark  4Ld00UQYL3aPcK4yOnv0JP             dio
# 1        girls, girls, girls  5Rso4igx5lTkTAbDEN9nuQ     mötley crüe
# 2                  red alert  72GcnatH6Q1IqRrNjOuukN      quiet riot
# 3                     poison  5XcZRgJv3zMhTqCyESjQrF    alice cooper
# 4        people of the night  6K4fiQRAp9QdwDdK5DKHcl           shout
# ..                       ...                     ...             ...
# 101           rock her bones  02m82m2wWh1dzfmkL5mDlX           shout
# 102        come out and play  3SPJpKR25VMjWwIo2JCL6k  twisted sister
# 103               seven seas  0vkP5rs4NqGdEW10oHstO8             tnt
# 104  rock me - 2005 remaster  5RK9Q1vogXWI60qVGDzTZA     great white
# 105           dream warriors  7AUFwSivoAvJoh1OJDLrGJ          dokken
#
# [106 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [Heavy Metal-80's Hair Metal-Power Ballads-Rock](https://open.spotify.com/playlist/1tvCfaqcXP2QEHgFWf0t17?si=02bcc9709c514252&nd=1)
# - by Solveig Seldal
# - 785 songs

# %%
results4 = get_playlist_tracks("Solveig Seldal","1tvCfaqcXP2QEHgFWf0t17")
len(results4)
# Out:
# 785

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results4

for r in results4:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf4 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf4['song_name'] = songdf4['song_name'].str.lower()
songdf4['artist'] = songdf4['artist'].str.lower()
songdf4
# Out:
#                      song_name                 song_id          artist
# 0    rock you like a hurricane  46QazXxQS0B31CnbRCy8CV       scorpions
# 1             cartesian dreams  26QQFxxg7EkPLwfAc2qCpy  house of lords
# 2                 i walk alone  5m8JHIXmasB1qOPCzfGVBr            jorn
# 3                   she's gone  2fvObZjCzCF57MKmn1ePPO      steelheart
# 4                slow an' easy  0qTvq8jgrRd2mu3Q7d4oQb      whitesnake
# ..                         ...                     ...             ...
# 780          bring me everyone  148V2ZB9jpUeJENStJjjDq        mustasch
# 781           the skeleton key  6IVKiq8Xxhvg03MUtu5smv           epica
# 782               head up high  0uRUJf3fZDrTGM9JksGZuZ        firewind
# 783               lost chapter  207K1MXwebxpXDS43OazOU       pentakill
# 784              edge of night  3Ro1AMjH9qdY3ZTWfxIFpN       pentakill
#
# [785 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [80's,rock,heavy metal and metal mix](https://open.spotify.com/playlist/2Rhu5twFe7cNUlRtadJtnw?si=91332b798c8045ca&nd=1)
# - by Nicholas Kauffmann
# - 668 songs

# %%
results5 = get_playlist_tracks("Nicholas Kauffmann","2Rhu5twFe7cNUlRtadJtnw")
len(results5)
# Out:
# 668

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results5

for r in results5:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf5 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf5['song_name'] = songdf5['song_name'].str.lower()
songdf5['artist'] = songdf5['artist'].str.lower()
songdf5
# Out:
#                       song_name                 song_id                 artist
# 0                      paranoid  3q9G9SvgdfE1fxlvoDIb20          black sabbath
# 1            kickstart my heart  7GonnnalI2s19OCQO1J7Tf            mötley crüe
# 2    bringin' on the heartbreak  5DKSOabxbMTF1oLdPp5bcs            def leppard
# 3             over the mountain  0i1RTnH2Lj5gTDRU5wtyT2          ozzy osbourne
# 4                    am i evil?  03pJkRoQU8Lrmgc14ffJGJ              metallica
# ..                          ...                     ...                    ...
# 663                     rock me  0u6toDywZABXlUBq76iPKW            great white
# 664          find your way back  1QlHzR2Nl7gJlb4n3OrtrV     jefferson starship
# 665                        jane  2RNd6VgxG19db0zs0M1C4Z     jefferson starship
# 666                  no way out  5ncLNCx0nnz763Aug1q4ay     jefferson starship
# 667         california dreamin'  1ZEOIhSn6BKErV59bIgn76  the mamas & the papas
#
# [668 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [Heavy Metal Classics](https://open.spotify.com/playlist/27gN69ebwiJRtXEboL12Ih?si=13cc331c40b04ae0&nd=1)
# - by Misi
# - 386 songs

# %%
results6 = get_playlist_tracks("Misi","27gN69ebwiJRtXEboL12Ih")
len(results6)
# Out:
# 386

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results6

for r in results6:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf6 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf6['song_name'] = songdf6['song_name'].str.lower()
songdf6['artist'] = songdf6['artist'].str.lower()
songdf6
# Out:
#                             song_name                 song_id  \
# 0                            paranoid  3q9G9SvgdfE1fxlvoDIb20
# 1         the trooper - 2015 remaster  4OROzZUy6gOWN4UGQVaZMF
# 2                       ace of spades  47FyQCd3TYLrZ9TU6MPaWK
# 3    run to the hills - 2015 remaster  4Zc7TCHzuNwL0AFBlyLdyr
# 4    fear of the dark - 2015 remaster  6p8eFfPw3nQkf37aT3AkmK
# ..                                ...                     ...
# 381                      over my head  54XuDwn7kL2PXGw6vUW6Hx
# 382                    wait and bleed  15DLl1r2zi07Ssq5RT1yT0
# 383                         powertrip  3azSRGmcZSaSZVV3Izg4Tg
# 384                         astronomy  67TDP21NkdDbavSA0sMk8v
# 385                            bomber  5FvOGIzAQuJyNaEM62mhIG
#
#                artist
# 0       black sabbath
# 1         iron maiden
# 2           motörhead
# 3         iron maiden
# 4         iron maiden
# ..                ...
# 381          king's x
# 382          slipknot
# 383    monster magnet
# 384  blue öyster cult
# 385         motörhead
#
# [386 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [80s Heavy Rock / Metal](https://open.spotify.com/playlist/0EPz7rNCG4jjzgHpxdM1nD?si=2acca1ad7dca4c6a&nd=1)
# - by rol-ba
# - 243 songs

# %%
results7 = get_playlist_tracks("rol-ba","0EPz7rNCG4jjzgHpxdM1nD")
len(results7)
# Out:
# 243

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results7

for r in results7:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf7 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf7['song_name'] = songdf7['song_name'].str.lower()
songdf7['artist'] = songdf7['artist'].str.lower()
songdf7
# Out:
#                                       song_name                 song_id  \
# 0                              breaking the law  2RaA6kIcvomt77qlIgGhCT
# 1                                 ace of spades  6EPRKhUOdiFSQwGBRBbvsZ
# 2                         cum on feel the noize  3vV3cr2TpPqFk07zxYUbla
# 3                                    holy diver  54yLLvpezvPO1lA3GspiZj
# 4    run to the hills - 1998 remastered version  2JS1iE5A5RHvUPH5Zl9jlF
# ..                                          ...                     ...
# 238                                 black metal  3yNoEJifUJdly8ucYoWRwl
# 239                                        evil  6LGoJAyN1xAqF3VJZt0MKx
# 240                                metal church  34LXW73avo8xz0NLiVuiow
# 241                   rock you like a hurricane  58XWGx7KNNkKneHdprcprX
# 242                            still loving you  7kjsCbksOZotNNHOvKsJJh
#
#             artist
# 0     judas priest
# 1        motörhead
# 2       quiet riot
# 3              dio
# 4      iron maiden
# ..             ...
# 238          venom
# 239  mercyful fate
# 240   metal church
# 241      scorpions
# 242      scorpions
#
# [243 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [80s Hard Rock / Heavy Metal](https://open.spotify.com/playlist/0iNXcT6n7EHngUO3JpaW6J?si=4d69f6297b8144c8&nd=1)
# - by Rolando Batista
# - 547 songs

# %%
results8 = get_playlist_tracks("Rolando Batista","0iNXcT6n7EHngUO3JpaW6J")
len(results8)
# Out:
# 547

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results8

for r in results8:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf8 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf8['song_name'] = songdf8['song_name'].str.lower()
songdf8['artist'] = songdf8['artist'].str.lower()
songdf8
# Out:
#                                              song_name  \
# 0                            rock you like a hurricane
# 1                                  sweet child o' mine
# 2                    summertime girls - studio version
# 3                                                 jump
# 4                                       rock the night
# ..                                                 ...
# 542                                            ingrown
# 543                                       united sheep
# 544                                      dominoes fall
# 545                                 life on your knees
# 546  proud to be loud (as heard in great expectations)
#
#                     song_id              artist
# 0    0XIvZ82aDF7JiSi3ZE320u           scorpions
# 1    4MhTFsyqIJnjsOweVcU8ug       guns n' roses
# 2    2kR3B09M6KeJnchOkxwszt                 y&t
# 3    2PfBSkCKZDXMsJogMT0wML           van halen
# 4    4NffXDmI70vw19P5Efoe0T              europe
# ..                      ...                 ...
# 542  1KTQLypZn07OlnGT38efvU            neurosis
# 543  6QA6acjmIhVnep0WrinGaV            neurosis
# 544  33S9AsrE3wmDzDwoQOzOS1            neurosis
# 545  1cnANrdgRpq8IwfS2tBm61            neurosis
# 546  4g115GpyzP0U1d7I5RuHJm  dead green mummies
#
# [547 rows x 3 columns]

# %% [markdown]
# -------

# %% [markdown]
# - ['80s Metal Classics](https://open.spotify.com/playlist/3KkzYovFLMOiaXrt72xY2d?si=038511fa54a1461c&nd=1)
# - by Gonzalo Andres Quintana
# - 336 songs

# %%
results9 = get_playlist_tracks("Gonzalo Andres Quintana","3KkzYovFLMOiaXrt72xY2d")
len(results9)
# Out:
# 336

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results9

for r in results9:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf9 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf9['song_name'] = songdf9['song_name'].str.lower()
songdf9['artist'] = songdf9['artist'].str.lower()
songdf9
# Out:
#                         song_name                 song_id         artist
# 0                      metal gods  0VFfZVCFNe1I2IIChVBR5m   judas priest
# 1                             one  64Ret7Tf2M8pDE4aqbW2tX      metallica
# 2                         we rock  5qo8HipgkkuQ9tItiBiTaO            dio
# 3                riding the storm  4hfpMRkHOW3xGt8zE8ogFk   running wild
# 4    wasted years - 2015 remaster  1HM7Vp84E4SMzdrZONg6bH    iron maiden
# ..                            ...                     ...            ...
# 331            soldier of fortune  6WkCJYM3wtIOZvskzHWYnt       loudness
# 332        the burning of atlanta  16sznMthzmElmJ4fPFP1aL       whiplash
# 333         power thrashing death  7x0eznaiq2CaLUfOqiUSvt       whiplash
# 334                the apparition  3KhTOoJDjpFhcAKUAbMxIB  fates warning
# 335                      guardian  6OWafYToeRoamwzuIFhtIh  fates warning
#
# [336 rows x 3 columns]

# %% [markdown]
# ------

# %% [markdown]
# - [80s Heavy Metal / Underrated playlist](https://open.spotify.com/playlist/41bkoMrOtBPKTIldGrgTGT?si=c96c2e3f5a654db7&nd=1)
# - by ocnarf_
# - 606 songs

# %%
results10 = get_playlist_tracks("ocnarf_","41bkoMrOtBPKTIldGrgTGT")
len(results10)
# Out:
# 606

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results10

for r in results10:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf10 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf10['song_name'] = songdf10['song_name'].str.lower()
songdf10['artist'] = songdf10['artist'].str.lower()
songdf10
# Out:
#                          song_name                 song_id            artist
# 0       wrathchild - 2015 remaster  1SpuDZ7y1W4vaCzHeLvsf7       iron maiden
# 1                   chaos descends  3vcnNJJNC1g7KoByCaQajL      cirith ungol
# 2                  dead on arrival  17dwaNuNN2WtEf44tOgVb5       grim reaper
# 3    i am the one you warned me of  5dvxMjve4VBNYSYkP1VIG3  blue öyster cult
# 4           rocking the night away  5dKUTtcf4bJvcZ3v5YvnMd       witch cross
# ..                             ...                     ...               ...
# 601              fire in the brain  3arsaI4qLpEL9vAX7z6pJl                oz
# 602                too hot to rock  4Sqe3SNeMajB0bal8GhqyZ         ironcross
# 603               midwinter nights  0cw0x5fneOxfHUm4QDOwvd             tarot
# 604               back in the fire  1542KEu4H2dSblQn2iFIrA             tarot
# 605                         pharao  0jB54mh5HFujdS6nsYpSjb             tarot
#
# [606 rows x 3 columns]

# %% [markdown]
# ----

# %% [markdown]
# - [Women of Heavy Metal](https://open.spotify.com/playlist/2nCbzvyUCzIiWhzxyPKNUO?si=1c87a9ddf7fa4214&nd=1)
# - by Michael
# - 361 songs

# %%
results11 = get_playlist_tracks("Michael","2nCbzvyUCzIiWhzxyPKNUO")
len(results11)
# Out:
# 361

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results11

for r in results11:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf11 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf11['song_name'] = songdf11['song_name'].str.lower()
songdf11['artist'] = songdf11['artist'].str.lower()
songdf11
# Out:
#                     song_name                 song_id               artist
# 0                      pisces  1XT5VDdxwI2Bx01MxURMcz               jinjer
# 1               rule of nines  1Uo51u6JqpIroI98zyhCvE            spiritbox
# 2    general of the dark army  5WDroVCEVjLayAJoqeuMR7  unleash the archers
# 3           reason to believe  02gIPDHCTuKgKEl2VlgPzt           arch enemy
# 4                     silvera  5uunXHE4kIW6uS4HWAXaOQ               gojira
# ..                        ...                     ...                  ...
# 356                holy diver  1B4syOWfRxrFYUYn6gieij      burning witches
# 357            wings of steel  1qNPzB8EXeVCD3O9da9qYD      burning witches
# 358                spellbound  4DXswc4p8mel7E6C1ZSHDq          lacuna coil
# 359                      burn  5flMLmYH9APBlSwlAv45ls    we are the fallen
# 360              never enough  4sIWOzf7LxpuGInB68CrLl                epica
#
# [361 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [Women singing Heavy Metal](https://open.spotify.com/playlist/3K2G0yetuJDUTJZt5Ey7Oo?si=e1fad9a0f7504e81&nd=1)
# - by Fiona
# - 81 songs

# %%
results12 = get_playlist_tracks("Fiona","3K2G0yetuJDUTJZt5Ey7Oo")
len(results12)
# Out:
# 81

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results12

for r in results12:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf12 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf12['song_name'] = songdf12['song_name'].str.lower()
songdf12['artist'] = songdf12['artist'].str.lower()
songdf12
# Out:
#                           song_name                 song_id  \
# 0                     sign of satan  4Jx6PfRbJbFjuWUz6Rd2mt
# 1                 (i'm your) victim  7399vKY7Q7QOPBMTNIEZBd
# 2                       night curse  1JxaFzaiN8HtrVovhTvxVt
# 3             i want you to rock me  6VtP45gz771bs1MTyo02bV
# 4                       black widow  35ZnecAxQaTgnoOpRNCbvy
# ..                              ...                     ...
# 76                     bad attitude  7KkTwKGjGxKjVt52ZBExVJ
# 77                         antidote  2U5WbPl1kN2T1F14lY6A6o
# 78  master of disaster - remastered  2Iqr4DVuR1b1JHpzBS9LDR
# 79             entoptic petroglyphs  2gmZflhQpWMqwUUlI23kaA
# 80                 lake of necrosis  56DOvJP7KyCBDz9OECs5eJ
#
#                 artist
# 0              warlock
# 1           girlschool
# 2   sign of the jackal
# 3                vixen
# 4      burning witches
# ..                 ...
# 76             hellion
# 77              furies
# 78        black knight
# 79    grendel's sÿster
# 80              mystik
#
# [81 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# - [Heavy Metal women](https://open.spotify.com/playlist/1Ry5N0xb6gN3qwjHWWiGey?si=f536a22c66e7486d&nd=1)
# - by megarel
# - 684 songs

# %%
results13 = get_playlist_tracks("megarel","1Ry5N0xb6gN3qwjHWWiGey")
len(results13)
# Out:
# 684

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results13

for r in results13:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf13 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf13['song_name'] = songdf13['song_name'].str.lower()
songdf13['artist'] = songdf13['artist'].str.lower()
songdf13
# Out:
#                              song_name                 song_id  \
# 0                     the second stone  1hIDjoxsQghoH6KB2NQWD7
# 1               the essence of silence  2cNbwuzTf58ZKyFkbUGCCF
# 2                    chemical insomnia  5VtnjY7HB9TeOiVvPhxlkr
# 3    reverence - living in the heart -  1KiM6LTyDliIxr6fXVLSRz
# 4         omen - the ghoulish malady -  63dcMTJd7dlHAKOdxeRU9t
# ..                                 ...                     ...
# 679         the pallbearer walks alone  4fGxMI4p6dOxXCutg1vrRx
# 680                   my sweet mystery  67K3qtJ8UQO7RPIqxEch6a
# 681                         until dawn  63JzJHjLkwlqZiCEnPDPkw
# 682                the deep & the dark  1bGs0xiAlMdKBpNSOq7Z9F
# 683           in the heat of the night  5yxDU6BiwFl1DEp6xRmKGj
#
#                   artist
# 0                  epica
# 1                  epica
# 2                  epica
# 3                  epica
# 4                  epica
# ..                   ...
# 679     the dark element
# 680     the dark element
# 681             elvellon
# 682  visions of atlantis
# 683           to/die/for
#
# [684 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [Metal women](https://open.spotify.com/playlist/3yE95McccejdsiqLTRTWWN?si=b4b0393a05c34538&nd=1)
# - by Neidy Johana Toro
# - 80 songs

# %%
results14 = get_playlist_tracks("Neidy Johana Toro","3yE95McccejdsiqLTRTWWN")
len(results14)
# Out:
# 80

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results14

for r in results14:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf14 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf14['song_name'] = songdf14['song_name'].str.lower()
songdf14['artist'] = songdf14['artist'].str.lower()
songdf14
# Out:
#              song_name                 song_id      artist
# 0     buried by terror  70Cd40ePlu1brALzwYNn7E      sinaya
# 1              gravity  5szGWBFHnhflYhFDHwNyyn  once human
# 2    i speak astronomy  702e8oJJ8fyTnyvEo6VA7u      jinjer
# 3          war eternal  0WZZENH0kt3O2cBE8q5IRq  arch enemy
# 4           tourniquet  1mEylG5rq7k9aU3WVW0jGW     cripper
# ..                 ...                     ...         ...
# 75            werewolf  5RkXKR2Mer5sD66Hy1PYlk  dehydrated
# 76           parallels  4vuQZVq89gIEjcL3bTIfbD  dehydrated
# 77         under ruins  5D14Kvd3GbWhZqKF2tp8MK     nervosa
# 78        sledgehammer  1ctuI255E9cSkUAxXYG1lP  once human
# 79  deceiver, deceiver  3jpGc7gcoTyQsrlfQ332Ql  arch enemy
#
# [80 rows x 3 columns]

# %% [markdown]
# ------

# %% [markdown]
# - [More Metal Goddesses / Women of metal / Heavy Queens](https://open.spotify.com/playlist/47T8Fz9uBTqMlxSGULx4J4?si=31e2c6bfa7c042df&nd=1)
# - by issok
# - 2397 songs

# %%
results15 = get_playlist_tracks("issok","47T8Fz9uBTqMlxSGULx4J4")
len(results15)
# Out:
# 2387

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results15

for r in results15:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf15 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf15['song_name'] = songdf15['song_name'].str.lower()
songdf15['artist'] = songdf15['artist'].str.lower()
songdf15
# Out:
#                                            song_name                 song_id  \
# 0                               voyage of the fallen  28jEzaO3cR4Sm47ipLhNGo
# 1                                         unembraced  40QknqrctohMaNrc90QWbS
# 2                                     in remembrance  0LG0FaQVYzisTrAKPa4Jin
# 3     i'd do anything for love (but i won't do that)  1rjUwi1saJzERBMrNkpNKF
# 4                                         ravenheart  3LNPdEhgpgyvR55F0L9eMc
# ...                                              ...                     ...
# 2382                          in vain - instrumental  6PG3TDO0RfnZSJzdJaY0YU
# 2383                        firelight - instrumental  721suJ3bEr7EojcwCFyWrU
# 2384                        mad world - instrumental  0Bv4YIlBJnwNpnFrRQCrrj
# 2385                     mercy mirror - instrumental  2no5b2crZ3NbvbRrijC3xS
# 2386                    trophy hunter - instrumental  2WxOZ2BvDoqIN7KZJkpGDm
#
#                  artist
# 0               xandria
# 1               xandria
# 2               xandria
# 3               xandria
# 4               xandria
# ...                 ...
# 2382  within temptation
# 2383  within temptation
# 2384  within temptation
# 2385  within temptation
# 2386  within temptation
#
# [2387 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [This is Doro](https://open.spotify.com/playlist/37i9dQZF1DZ06evO3lMIzh)
# - by Spotify
# - 50 songs

# %%
results16 = get_playlist_tracks("Spotify","37i9dQZF1DZ06evO3lMIzh")
len(results16)
# Out:
# 50

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results16

for r in results16:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf16 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf16['song_name'] = songdf16['song_name'].str.lower()
songdf16['artist'] = songdf16['artist'].str.lower()
songdf16
# Out:
#                                             song_name                 song_id  \
# 0                                           für immer  7GBt0SpACpV3HXad7tMY0U
# 1                               dancing with an angel  24V2sAxzW67whN6kbO0vt1
# 2                                          lift me up  5FP8EUI8oLePiW8hEfy9BV
# 3                                     even angels cry  00CKqQSBhAr2gePvyIzk0P
# 4           a dream that cannot be (feat. doro pesch)  0BQO60IlkGyAcSlFGml79G
# 5                                          all we are  1hHj5VZDD0FbXQwKpKiPyX
# 6                   if i can't have you - no one will  7gTbLA6ksuzbxEbqrhpt50
# 7                           egypt (the chains are on)  08IkDWsiDhYtRUlKPxENvk
# 8                                  nichts bleibt mehr  3JhCAGwqY1goilCzj3n8EN
# 9                                    breaking the law  3UJhB9zmE7dCX8KqH2JEQy
# 10                                      all for metal  7ECsTXBu0NsHrXte3PP36s
# 11                                     it still hurts  4G0UdoJ120BHNZukephLWg
# 12                            walking with the angels  3rcQfO8DzCmLC9TMQQXalG
# 13                              legacy (intro) - live  4WM5ai9PWzpGvrzm4QYicj
# 14                                         1000 years  7rSCibeWoBJoOG9JKszcWs
# 15                    love me in black - 2020 version  7ff1Img4ScXOJi0Mfu6Qih
# 16                             a whiter shade of pale  7B5OsMidvkRxfINzbRBWYC
# 17                               kiss of death - live  68mzM2vgKfPQCEus9HL2DM
# 18  where the wild wolves have gone (feat. doro pe...  14JVBviJgcqmGxfO7KlhL6
# 19                                  angel in the dark  1sPCeOvh7dCAOtJTPhMWi9
# 20                                 tausend mal gelebt  2ullWuR07XoTwOyNWszo7M
# 21                               touch of evil - live  2DFHkEyG7RQzHor67eBfEP
# 22                                           hoffnung  1W1GLa4EYqKhqXSBHle6NQ
# 23                                        lonely wolf  2YFIxC7ykNvuNsz7eYwBQl
# 24                                let love rain on me  7kgoLZugeoJclVxMLF7r9i
# 25                                             salome  1MqDnOphHpSXX1mVK8Sv4U
# 26                                      alles ist gut  0hZyPlMIj6oznMEJvcEYaz
# 27                                         black rose  4m6r4M964oZpp2G0I7dEsR
# 28                                        metal tango  3sglfxqLAhq9yeF5jpYepf
# 29                                i know you by heart  6584fVke0wvDnZANC8KQQp
# 30                                  fall for me again  5fpNMsoQYfSa8xlIDkwkAI
# 31                                          brickwall  7aBYCpaludr9EVl2Nq9E9A
# 32                               nothing else matters  5pZIdQ3eQLJDR7LGbNko5f
# 33                         the alliance of hellhoundz  5tCcJVscUnLOssG1NnEHjA
# 34             llueva en mi tu amor - spanish version  2ntUdwe20dITVK3aPlT5pu
# 35                                      bis aufs blut  5aa8AkY5aM1Wm2HKuTJiDa
# 36                                 i'll be holding on  2s77tcXn7sL5Fd3DFkyXaX
# 37                         raise your fist in the air  00QqqiF4EYMH6JhRvQNYRS
# 38                                 ein stück ewigkeit  42VbptVP9ebAsxelWsG9lt
# 39                             east meets west - live  2x8AZTI6gLXEpAUhxjdLeK
# 40         in freiheit stirbt mein herz - single edit  5EjTC8TopomBOAxtNxmENC
# 41                                   beyond the trees  7nJRyVrB671C8Vsfpd8qEW
# 42                                             helden  6pEfLtjimY7WfDDKbSvtxE
# 43                                       black ballad  7dJ3dETeHaoRMHVRWe8gbN
# 44                            cold, cold world - live  5l7TJXavZVRpwcyfDhY6nu
# 45                                    world gone wild  3MCv5kY2WB7GOlbsHZxmkS
# 46                                            seelied  0URpWr1h979000HTnEG6Hg
# 47                                backstage to heaven  66kTuff9bzg8uzPjW1Q438
# 48                          alone again - bonus track  5TCC99LnrBfpsTTDP9eqa9
# 49                   constant danger - live unplugged  4G9ysbYGGBnAZ0PRWZVCmN
#
#              artist
# 0              doro
# 1            u.d.o.
# 2              doro
# 3              doro
# 4       amon amarth
# 5              doro
# 6              doro
# 7              doro
# 8              doro
# 9              doro
# 10             doro
# 11             doro
# 12             doro
# 13             doro
# 14             doro
# 15             doro
# 16             doro
# 17             doro
# 18        powerwolf
# 19             doro
# 20             doro
# 21             doro
# 22             doro
# 23             doro
# 24             doro
# 25  saltatio mortis
# 26             doro
# 27             doro
# 28             doro
# 29             doro
# 30             doro
# 31             doro
# 32             doro
# 33      destruction
# 34             doro
# 35             doro
# 36             doro
# 37             doro
# 38             doro
# 39             doro
# 40             doro
# 41             doro
# 42             doro
# 43             doro
# 44             doro
# 45             doro
# 46             doro
# 47             doro
# 48             doro
# 49             doro

# %% [markdown]
# -----

# %% [markdown]
# - [Metal BIG 25](https://open.spotify.com/playlist/2SLuYNdsCmBRYkNYjL8MXj)
# - by edgar.salas
# - 1008 songs

# %%
results17 = get_playlist_tracks("edgar.salas","2SLuYNdsCmBRYkNYjL8MXj")
len(results17)
# Out:
# 1008

# %%
# collect data with a loop
song_name=[]
song_id=[]
artist=[]
playlist=results17

for r in results17:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf17 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf17['song_name'] = songdf17['song_name'].str.lower()
songdf17['artist'] = songdf17['artist'].str.lower()
songdf17
# Out:
#                   song_name                 song_id                    artist
# 0              god of light  1zw5RlIr77z3IdiBfxoXjr                    danzig
# 1           suicidal maniac  4msqNBGHuOZ59LOjGZITvV       suicidal tendencies
# 2                    mother  5JtuIHVfsYBFAVrHwjUddj                    danzig
# 3                am i demon  2Bt7cSAgiPWpM2dOU6VAg1                    danzig
# 4          expendable youth  2pdvKfAvuwNHGG2y7vMC1y                    slayer
# ...                     ...                     ...                       ...
# 1003             down rodeo  40L8L7344pPMCjlZc19RQU  rage against the machine
# 1004         without a face  3DdOsUq1M9mJBFVR0xbSOx  rage against the machine
# 1005             roll right  5tYosD9TicWDYO3kAE4ADp  rage against the machine
# 1006  year of tha boomerang  69oLqnnqggg6v7JMw9VIbf  rage against the machine
# 1007      persona non grata  12HenFSS0P7hgIznVBxsde                    exodus
#
# [1008 rows x 3 columns]

# %% [markdown]
# -----

# %% [markdown]
# - [True 80s Heavy Metal](https://open.spotify.com/playlist/4hwXRbhEmxzhAxKBNThKMX?si=a70ef3a321a845e4&nd=1)
# - by guitaromnivore
# - 1670 songs

# %%
results18 = get_playlist_tracks("guitaromnivore","4hwXRbhEmxzhAxKBNThKMX")
len(results18)
# Out:
# 1681

# %%
song_name=[]
song_id=[]
artist=[]
playlist=results18

for r in results18:
    song_name.append(r['track']['name'])
    song_id.append(r['track']['id'])
    artist.append(r['track']['artists'][0]['name'])

songdf18 = pd.DataFrame({"song_name":song_name, "song_id":song_id, "artist":artist} )
songdf18['song_name'] = songdf18['song_name'].str.lower()
songdf18['artist'] = songdf18['artist'].str.lower()
songdf18
# Out:
#                             song_name                 song_id          artist
# 0                       crystal logic  1bP2StEGAk87l0YYoifag8    manilla road
# 1                             forever  2jE86fMXxqYh5xDEvl1PsP             y&t
# 2     heaven and hell - 2008 remaster  3Jl5GohfNwozDmpzmQBLDI   black sabbath
# 3                       kyrie eleison  5PBSbTueCPoqAmFq1rRcKr   fates warning
# 4                phantom of the opera  33hy20OHQwMFhDlkaDsi6s     iron maiden
# ...                               ...                     ...             ...
# 1676                       the hunger  0t7drKxKQEPc8aM8HQNXc1     black death
# 1677         night of the living dead  7stiM8xwmRqXd7IAnOU1dl     black death
# 1678                     streetwalker  4fhm5jbYs1jVhmslZ1u3uS     black death
# 1679                      night rider  4lX9CG5Ya28AAzvQCsLJVI     pagan altar
# 1680                    eye's of fire  3GIVW0jDF7h9fltBpMiioG  medieval steel
#
# [1681 rows x 3 columns]

# %% [markdown]
# ## Concat all playlists

# %% [markdown]
# songdf2 - songdf13

# %%
songdf1 = [songdf2,songdf3,songdf4,songdf5,songdf6,songdf7,songdf8,songdf9,songdf10,songdf11,songdf12,songdf13,songdf14,songdf15,songdf16,songdf17]
songdf = pd.concat(songdf1)
songdf.reset_index(drop=True, inplace=True)
songdf
# Out:
#                                               song_name  \
# 0                                              paranoid
# 1                                         ace of spades
# 2                                           crazy train
# 3     the number of the beast - 1998 remastered version
# 4        hallowed be thy name - 1998 remastered version
# ...                                                 ...
# 8820                                         down rodeo
# 8821                                     without a face
# 8822                                         roll right
# 8823                              year of tha boomerang
# 8824                                  persona non grata
#
#                      song_id                    artist
# 0     3L8WgDYS5TtwbyxOPSAiFf             black sabbath
# 1     47FyQCd3TYLrZ9TU6MPaWK                 motörhead
# 2     3ao8tE7CIEo3KehDQYYoWv             ozzy osbourne
# 3     1s4Ie0cT6P73SRSfh3oyGW               iron maiden
# 4     1iGXvUsVVkYBas0Cniw6NB               iron maiden
# ...                      ...                       ...
# 8820  40L8L7344pPMCjlZc19RQU  rage against the machine
# 8821  3DdOsUq1M9mJBFVR0xbSOx  rage against the machine
# 8822  5tYosD9TicWDYO3kAE4ADp  rage against the machine
# 8823  69oLqnnqggg6v7JMw9VIbf  rage against the machine
# 8824  12HenFSS0P7hgIznVBxsde                    exodus
#
# [8825 rows x 3 columns]

# %%
# how many unique songs are in the df?
songdf['song_id'].nunique()
# Out:
# 7524

# %%
# keep fast dont mantain any of the duplicates, last or first mantain one of them
songdf = songdf.drop_duplicates(subset='song_id', keep="last")
songdf.reset_index(drop=True, inplace=True)
songdf
# Out:
#                   song_name                 song_id                    artist
# 0                  paranoid  3L8WgDYS5TtwbyxOPSAiFf             black sabbath
# 1               crazy train  3ao8tE7CIEo3KehDQYYoWv             ozzy osbourne
# 2                  war pigs  1mnXT8zNssefzrRkeuD8Ov             black sabbath
# 3             back in black  6SPOlvJok6QmNWkvUVPQMs                     ac/dc
# 4                  iron man  5TFyNdCLlC1ZRuwczqaS97             black sabbath
# ...                     ...                     ...                       ...
# 7519             down rodeo  40L8L7344pPMCjlZc19RQU  rage against the machine
# 7520         without a face  3DdOsUq1M9mJBFVR0xbSOx  rage against the machine
# 7521             roll right  5tYosD9TicWDYO3kAE4ADp  rage against the machine
# 7522  year of tha boomerang  69oLqnnqggg6v7JMw9VIbf  rage against the machine
# 7523      persona non grata  12HenFSS0P7hgIznVBxsde                    exodus
#
# [7524 rows x 3 columns]

# %%
songdf['song_id'].nunique()
# Out:
# 7524

# %% [markdown]
# ## Get the audio features

# %%
songdf.rename(columns={'song_id': 'id'},inplace=True, errors='raise')
# Out:
# D:\Programas\Anaconda\envs\classenv\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
songdf
# Out:
#                   song_name                      id                    artist
# 0                  paranoid  3L8WgDYS5TtwbyxOPSAiFf             black sabbath
# 1               crazy train  3ao8tE7CIEo3KehDQYYoWv             ozzy osbourne
# 2                  war pigs  1mnXT8zNssefzrRkeuD8Ov             black sabbath
# 3             back in black  6SPOlvJok6QmNWkvUVPQMs                     ac/dc
# 4                  iron man  5TFyNdCLlC1ZRuwczqaS97             black sabbath
# ...                     ...                     ...                       ...
# 7519             down rodeo  40L8L7344pPMCjlZc19RQU  rage against the machine
# 7520         without a face  3DdOsUq1M9mJBFVR0xbSOx  rage against the machine
# 7521             roll right  5tYosD9TicWDYO3kAE4ADp  rage against the machine
# 7522  year of tha boomerang  69oLqnnqggg6v7JMw9VIbf  rage against the machine
# 7523      persona non grata  12HenFSS0P7hgIznVBxsde                    exodus
#
# [7524 rows x 3 columns]

# %%
import numpy as np

# %%
features = []
for n, chunk_series in songdf.groupby(np.arange(len(songdf)) // 50).id:
    features += sp.audio_features([*map(str, chunk_series)])
features_df = pd.DataFrame.from_dict(filter(None, features))
tracks_with_features_df = songdf.merge(features_df, on=['id'], how='inner')

# %%
tracks_with_features_df
# Out:
#                   song_name                      id                    artist  \
# 0                  paranoid  3L8WgDYS5TtwbyxOPSAiFf             black sabbath
# 1               crazy train  3ao8tE7CIEo3KehDQYYoWv             ozzy osbourne
# 2                  war pigs  1mnXT8zNssefzrRkeuD8Ov             black sabbath
# 3             back in black  6SPOlvJok6QmNWkvUVPQMs                     ac/dc
# 4                  iron man  5TFyNdCLlC1ZRuwczqaS97             black sabbath
# ...                     ...                     ...                       ...
# 7519             down rodeo  40L8L7344pPMCjlZc19RQU  rage against the machine
# 7520         without a face  3DdOsUq1M9mJBFVR0xbSOx  rage against the machine
# 7521             roll right  5tYosD9TicWDYO3kAE4ADp  rage against the machine
# 7522  year of tha boomerang  69oLqnnqggg6v7JMw9VIbf  rage against the machine
# 7523      persona non grata  12HenFSS0P7hgIznVBxsde                    exodus
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.418   0.668    6   -11.297     0       0.0820      0.000143
# 1            0.473   0.918    9    -3.580     1       0.0566      0.014500
# 2            0.452   0.701    9    -9.534     1       0.0677      0.145000
# 3            0.436   0.710    9    -5.666     1       0.0350      0.011300
# 4            0.339   0.824    9    -9.522     1       0.0938      0.005210
# ...            ...     ...  ...       ...   ...          ...           ...
# 7519         0.427   0.867    7    -9.077     1       0.1280      0.005350
# 7520         0.425   0.808    9    -8.376     0       0.2210      0.005340
# 7521         0.527   0.789    9    -8.049     1       0.0694      0.014000
# 7522         0.354   0.711    4   -10.134     0       0.1490      0.000499
# 7523         0.455   0.975    2    -6.137     1       0.0822      0.000022
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.001130    0.1730    0.379  162.663  audio_features
# 1             0.002480    0.3270    0.586  137.606  audio_features
# 2             0.008170    0.2670    0.519   90.157  audio_features
# 3             0.008110    0.0767    0.735   92.887  audio_features
# 4             0.004320    0.0803    0.538  154.573  audio_features
# ...                ...       ...      ...      ...             ...
# 7519          0.000846    0.0785    0.560  170.256  audio_features
# 7520          0.179000    0.1750    0.369   92.257  audio_features
# 7521          0.013300    0.3810    0.452   86.137  audio_features
# 7522          0.000423    0.2450    0.518   84.268  audio_features
# 7523          0.041500    0.3090    0.294  128.377  audio_features
#
#                                        uri  \
# 0     spotify:track:3L8WgDYS5TtwbyxOPSAiFf
# 1     spotify:track:3ao8tE7CIEo3KehDQYYoWv
# 2     spotify:track:1mnXT8zNssefzrRkeuD8Ov
# 3     spotify:track:6SPOlvJok6QmNWkvUVPQMs
# 4     spotify:track:5TFyNdCLlC1ZRuwczqaS97
# ...                                    ...
# 7519  spotify:track:40L8L7344pPMCjlZc19RQU
# 7520  spotify:track:3DdOsUq1M9mJBFVR0xbSOx
# 7521  spotify:track:5tYosD9TicWDYO3kAE4ADp
# 7522  spotify:track:69oLqnnqggg6v7JMw9VIbf
# 7523  spotify:track:12HenFSS0P7hgIznVBxsde
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3L8WgDYS5Ttw...
# 1     https://api.spotify.com/v1/tracks/3ao8tE7CIEo3...
# 2     https://api.spotify.com/v1/tracks/1mnXT8zNssef...
# 3     https://api.spotify.com/v1/tracks/6SPOlvJok6Qm...
# 4     https://api.spotify.com/v1/tracks/5TFyNdCLlC1Z...
# ...                                                 ...
# 7519  https://api.spotify.com/v1/tracks/40L8L7344pPM...
# 7520  https://api.spotify.com/v1/tracks/3DdOsUq1M9mJ...
# 7521  https://api.spotify.com/v1/tracks/5tYosD9TicWD...
# 7522  https://api.spotify.com/v1/tracks/69oLqnnqggg6...
# 7523  https://api.spotify.com/v1/tracks/12HenFSS0P7h...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3L8W...       167933
# 1     https://api.spotify.com/v1/audio-analysis/3ao8...       290067
# 2     https://api.spotify.com/v1/audio-analysis/1mnX...       474560
# 3     https://api.spotify.com/v1/audio-analysis/6SPO...       255200
# 4     https://api.spotify.com/v1/audio-analysis/5TFy...       354240
# ...                                                 ...          ...
# 7519  https://api.spotify.com/v1/audio-analysis/40L8...       320627
# 7520  https://api.spotify.com/v1/audio-analysis/3DdO...       216907
# 7521  https://api.spotify.com/v1/audio-analysis/5tYo...       260267
# 7522  https://api.spotify.com/v1/audio-analysis/69oL...       239640
# 7523  https://api.spotify.com/v1/audio-analysis/12He...       450667
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7519               4
# 7520               4
# 7521               4
# 7522               4
# 7523               4
#
# [7524 rows x 20 columns]

# %%
# store it in a csv
# tracks_with_features_df.to_csv(r'tracks_with_features_df.csv', index = False, header = True)

# %% [markdown]
# ## CLUSTERING - UNSUPERVISED LEARNING

# %% [markdown]
# ## ingredients

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import plotly 
import plotly.graph_objs as go
from sklearn.cluster import KMeans 
from sklearn import datasets

# %% [markdown]
# ## Import and explore the data - EDA

# %%
#preview 
tracks_with_features_df.head()
# Out:
#        song_name                      id         artist  danceability  energy  \
# 0       paranoid  3L8WgDYS5TtwbyxOPSAiFf  black sabbath         0.418   0.668
# 1    crazy train  3ao8tE7CIEo3KehDQYYoWv  ozzy osbourne         0.473   0.918
# 2       war pigs  1mnXT8zNssefzrRkeuD8Ov  black sabbath         0.452   0.701
# 3  back in black  6SPOlvJok6QmNWkvUVPQMs          ac/dc         0.436   0.710
# 4       iron man  5TFyNdCLlC1ZRuwczqaS97  black sabbath         0.339   0.824
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    6   -11.297     0       0.0820      0.000143           0.00113    0.1730
# 1    9    -3.580     1       0.0566      0.014500           0.00248    0.3270
# 2    9    -9.534     1       0.0677      0.145000           0.00817    0.2670
# 3    9    -5.666     1       0.0350      0.011300           0.00811    0.0767
# 4    9    -9.522     1       0.0938      0.005210           0.00432    0.0803
#
#    valence    tempo            type                                   uri  \
# 0    0.379  162.663  audio_features  spotify:track:3L8WgDYS5TtwbyxOPSAiFf
# 1    0.586  137.606  audio_features  spotify:track:3ao8tE7CIEo3KehDQYYoWv
# 2    0.519   90.157  audio_features  spotify:track:1mnXT8zNssefzrRkeuD8Ov
# 3    0.735   92.887  audio_features  spotify:track:6SPOlvJok6QmNWkvUVPQMs
# 4    0.538  154.573  audio_features  spotify:track:5TFyNdCLlC1ZRuwczqaS97
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3L8WgDYS5Ttw...
# 1  https://api.spotify.com/v1/tracks/3ao8tE7CIEo3...
# 2  https://api.spotify.com/v1/tracks/1mnXT8zNssef...
# 3  https://api.spotify.com/v1/tracks/6SPOlvJok6Qm...
# 4  https://api.spotify.com/v1/tracks/5TFyNdCLlC1Z...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3L8W...       167933
# 1  https://api.spotify.com/v1/audio-analysis/3ao8...       290067
# 2  https://api.spotify.com/v1/audio-analysis/1mnX...       474560
# 3  https://api.spotify.com/v1/audio-analysis/6SPO...       255200
# 4  https://api.spotify.com/v1/audio-analysis/5TFy...       354240
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
tracks_with_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7524 entries, 0 to 7523
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_name         7524 non-null   object
#  1   id                7524 non-null   object
#  2   artist            7524 non-null   object
#  3   danceability      7524 non-null   float64
#  4   energy            7524 non-null   float64
#  5   key               7524 non-null   int64
#  6   loudness          7524 non-null   float64
#  7   mode              7524 non-null   int64
#  8   speechiness       7524 non-null   float64
#  9   acousticness      7524 non-null   float64
#  10  instrumentalness  7524 non-null   float64
#  11  liveness          7524 non-null   float64
#  12  valence           7524 non-null   float64
#  13  tempo             7524 non-null   float64
#  14  type              7524 non-null   object
#  15  uri               7524 non-null   object
#  16  track_href        7524 non-null   object
#  17  analysis_url      7524 non-null   object
#  18  duration_ms       7524 non-null   int64
#  19  time_signature    7524 non-null   int64
# dtypes: float64(9), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
tracks_with_features_df.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   7524.000000  7524.000000  7524.000000  7524.000000  7524.000000
# mean       0.418782     0.832270     5.371478    -6.559703     0.505981
# std        0.123464     0.160272     3.485309     3.105137     0.499997
# min        0.000000     0.006670     0.000000   -36.756000     0.000000
# 25%        0.330000     0.773000     2.000000    -8.066750     0.000000
# 50%        0.428000     0.887000     5.000000    -5.761000     1.000000
# 75%        0.502000     0.945000     9.000000    -4.374000     1.000000
# max        0.929000     0.999000    11.000000     0.878000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness     valence  \
# count  7524.000000   7524.000000       7524.000000  7524.000000  7524.00000
# mean      0.073742      0.048318          0.098352     0.224312     0.36664
# std       0.052462      0.137031          0.219908     0.176741     0.19856
# min       0.000000      0.000000          0.000000     0.015100     0.00000
# 25%       0.039600      0.000181          0.000018     0.101750     0.21300
# 50%       0.056900      0.001780          0.001080     0.159000     0.34000
# 75%       0.088100      0.019000          0.044575     0.311000     0.49700
# max       0.505000      0.994000          0.994000     0.993000     0.97800
#
#              tempo   duration_ms  time_signature
# count  7524.000000  7.524000e+03     7524.000000
# mean    126.637288  2.743800e+05        3.925970
# std      28.975499  8.878315e+04        0.345835
# min       0.000000  8.093000e+03        0.000000
# 25%     104.004750  2.245435e+05        4.000000
# 50%     125.435000  2.606470e+05        4.000000
# 75%     145.359000  3.079730e+05        4.000000
# max     211.270000  1.505453e+06        5.000000

# %%
tracks_with_feats_num = tracks_with_features_df._get_numeric_data()
tracks_with_feats_num
# maybe convert the index into a column as a key to connect with the whole df?
# or put the song name or song id as index? ( i prefer 1st option i think)
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.418   0.668    6   -11.297     0       0.0820      0.000143
# 1            0.473   0.918    9    -3.580     1       0.0566      0.014500
# 2            0.452   0.701    9    -9.534     1       0.0677      0.145000
# 3            0.436   0.710    9    -5.666     1       0.0350      0.011300
# 4            0.339   0.824    9    -9.522     1       0.0938      0.005210
# ...            ...     ...  ...       ...   ...          ...           ...
# 7519         0.427   0.867    7    -9.077     1       0.1280      0.005350
# 7520         0.425   0.808    9    -8.376     0       0.2210      0.005340
# 7521         0.527   0.789    9    -8.049     1       0.0694      0.014000
# 7522         0.354   0.711    4   -10.134     0       0.1490      0.000499
# 7523         0.455   0.975    2    -6.137     1       0.0822      0.000022
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.001130    0.1730    0.379  162.663       167933
# 1             0.002480    0.3270    0.586  137.606       290067
# 2             0.008170    0.2670    0.519   90.157       474560
# 3             0.008110    0.0767    0.735   92.887       255200
# 4             0.004320    0.0803    0.538  154.573       354240
# ...                ...       ...      ...      ...          ...
# 7519          0.000846    0.0785    0.560  170.256       320627
# 7520          0.179000    0.1750    0.369   92.257       216907
# 7521          0.013300    0.3810    0.452   86.137       260267
# 7522          0.000423    0.2450    0.518   84.268       239640
# 7523          0.041500    0.3090    0.294  128.377       450667
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 7519               4
# 7520               4
# 7521               4
# 7522               4
# 7523               4
#
# [7524 rows x 13 columns]

# %%
tracks_with_feats_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7524 entries, 0 to 7523
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      7524 non-null   float64
#  1   energy            7524 non-null   float64
#  2   key               7524 non-null   int64
#  3   loudness          7524 non-null   float64
#  4   mode              7524 non-null   int64
#  5   speechiness       7524 non-null   float64
#  6   acousticness      7524 non-null   float64
#  7   instrumentalness  7524 non-null   float64
#  8   liveness          7524 non-null   float64
#  9   valence           7524 non-null   float64
#  10  tempo             7524 non-null   float64
#  11  duration_ms       7524 non-null   int64
#  12  time_signature    7524 non-null   int64
# dtypes: float64(9), int64(4)
# memory usage: 822.9 KB

# %%
tracks_with_feats_num.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   7524.000000  7524.000000  7524.000000  7524.000000  7524.000000
# mean       0.418782     0.832270     5.371478    -6.559703     0.505981
# std        0.123464     0.160272     3.485309     3.105137     0.499997
# min        0.000000     0.006670     0.000000   -36.756000     0.000000
# 25%        0.330000     0.773000     2.000000    -8.066750     0.000000
# 50%        0.428000     0.887000     5.000000    -5.761000     1.000000
# 75%        0.502000     0.945000     9.000000    -4.374000     1.000000
# max        0.929000     0.999000    11.000000     0.878000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness     valence  \
# count  7524.000000   7524.000000       7524.000000  7524.000000  7524.00000
# mean      0.073742      0.048318          0.098352     0.224312     0.36664
# std       0.052462      0.137031          0.219908     0.176741     0.19856
# min       0.000000      0.000000          0.000000     0.015100     0.00000
# 25%       0.039600      0.000181          0.000018     0.101750     0.21300
# 50%       0.056900      0.001780          0.001080     0.159000     0.34000
# 75%       0.088100      0.019000          0.044575     0.311000     0.49700
# max       0.505000      0.994000          0.994000     0.993000     0.97800
#
#              tempo   duration_ms  time_signature
# count  7524.000000  7.524000e+03     7524.000000
# mean    126.637288  2.743800e+05        3.925970
# std      28.975499  8.878315e+04        0.345835
# min       0.000000  8.093000e+03        0.000000
# 25%     104.004750  2.245435e+05        4.000000
# 50%     125.435000  2.606470e+05        4.000000
# 75%     145.359000  3.079730e+05        4.000000
# max     211.270000  1.505453e+06        5.000000

# %%
#look at the distribution 
tracks_with_feats_num.hist(bins=15, figsize=(10,10));

# %% [markdown]
# #### awareness of KMEANS restrictions
# - everything must be numerical
# - ideally similar scales for all data points

# %%
## reshape - state to index # not needed now

# %%
# arrests.index=arrests.iloc[:,0]
#index location function [:,_]

# %%
#keep columns 2-4
# arrests=arrests.iloc[:,1:5]

# %%
#delete header name for index
# arrests.rename_axis(None,inplace=True)

# %% [markdown]
# ## Visualise to look for patterns
#
# + how to show 4 numerical fields in one 2d visual ?
# + use colour and size plus two axis

# %%
plt.scatter(tracks_with_feats_num.iloc[:,0],tracks_with_feats_num.iloc[:,3],tracks_with_feats_num.iloc[:,10],tracks_with_feats_num.iloc[:,1])
#x=danceability, y=loudness, size=tempo, colour=energy

# %%
plt.scatter(tracks_with_feats_num.iloc[:,0],tracks_with_feats_num.iloc[:,3],tracks_with_feats_num.iloc[:,7],tracks_with_feats_num.iloc[:,1])
#x=danceability, y=loudness, size=instrumentalness, colour=energy

# %%
plt.scatter(tracks_with_feats_num.iloc[:,1], #x= energy
            tracks_with_feats_num.iloc[:,3], #y=loudness
            tracks_with_feats_num.iloc[:,0], #size=danceability
            tracks_with_feats_num.iloc[:,7]) #colour=instrumentalness

# %%
tracks_with_feats_num.iloc[:,1]
# Out:
# 0       0.668
# 1       0.918
# 2       0.701
# 3       0.710
# 4       0.824
#         ...
# 7519    0.867
# 7520    0.808
# 7521    0.789
# 7522    0.711
# 7523    0.975
# Name: energy, Length: 7524, dtype: float64

# %% [markdown]
# ## Apply Clustering

# %%
kmeans=KMeans(n_clusters=200)

# %%
cluster=kmeans.fit(tracks_with_feats_num)

# %% [markdown]
# ## Explore clusters

# %%
cluster.cluster_centers_
# Out:
# array([[4.07675325e-01, 8.27259740e-01, 4.84415584e+00, ...,
#         1.25597234e+02, 3.08613143e+05, 3.80519481e+00],
#        [4.59488889e-01, 8.40433333e-01, 5.54444444e+00, ...,
#         1.26557533e+02, 2.18372589e+05, 3.96666667e+00],
#        [3.97000000e-01, 8.19857143e-01, 3.85714286e+00, ...,
#         1.04978571e+02, 5.16190571e+05, 4.14285714e+00],
#        ...,
#        [3.82600000e-01, 5.50200000e-01, 5.60000000e+00, ...,
#         1.29296200e+02, 7.76508000e+04, 4.00000000e+00],
#        [2.97333333e-01, 8.13000000e-01, 3.33333333e+00, ...,
#         1.58539333e+02, 6.06338000e+05, 4.00000000e+00],
#        [3.37153846e-01, 8.46000000e-01, 5.38461538e+00, ...,
#         1.35678846e+02, 4.09764154e+05, 3.84615385e+00]])

# %%
cluster.labels_
# Out:
# array([176, 181,  69, ...,  73, 182, 116])

# %%
#bring cluster into data frame
tracks_with_feats_num_c=tracks_with_feats_num.copy()
tracks_with_feats_num_c['cluster']=cluster.labels_
tracks_with_feats_num_c.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.418   0.668    6   -11.297     0       0.0820      0.000143
# 1         0.473   0.918    9    -3.580     1       0.0566      0.014500
# 2         0.452   0.701    9    -9.534     1       0.0677      0.145000
# 3         0.436   0.710    9    -5.666     1       0.0350      0.011300
# 4         0.339   0.824    9    -9.522     1       0.0938      0.005210
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.00113    0.1730    0.379  162.663       167933               4
# 1           0.00248    0.3270    0.586  137.606       290067               4
# 2           0.00817    0.2670    0.519   90.157       474560               4
# 3           0.00811    0.0767    0.735   92.887       255200               4
# 4           0.00432    0.0803    0.538  154.573       354240               4
#
#    cluster
# 0      176
# 1      181
# 2       69
# 3      141
# 4       55

# %%
tracks_with_feats_num_c["cluster"].value_counts()
# Out:
# 56     127
# 23     107
# 141    106
# 115    103
# 157    100
#       ...
# 32       1
# 28       1
# 3        1
# 183      1
# 78       1
# Name: cluster, Length: 200, dtype: int64

# %% [markdown]
# ## Visually explore clusters

# %%
### 2 fields at a time with cluster on colour

# %%
tracks_with_feats_num_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7524 entries, 0 to 7523
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      7524 non-null   float64
#  1   energy            7524 non-null   float64
#  2   key               7524 non-null   int64
#  3   loudness          7524 non-null   float64
#  4   mode              7524 non-null   int64
#  5   speechiness       7524 non-null   float64
#  6   acousticness      7524 non-null   float64
#  7   instrumentalness  7524 non-null   float64
#  8   liveness          7524 non-null   float64
#  9   valence           7524 non-null   float64
#  10  tempo             7524 non-null   float64
#  11  duration_ms       7524 non-null   int64
#  12  time_signature    7524 non-null   int64
#  13  cluster           7524 non-null   int32
# dtypes: float64(9), int32(1), int64(4)
# memory usage: 852.3 KB

# %%
plt.scatter(tracks_with_feats_num_c.iloc[:,0],
            tracks_with_feats_num_c.iloc[:,1],
            c=tracks_with_feats_num_c.iloc[:,3]);
# plot 2 numeric values with the cluster to examine it

# %%
plt.scatter(tracks_with_feats_num_c.iloc[:,2],
            tracks_with_feats_num_c.iloc[:,3],
            c=tracks_with_feats_num_c.iloc[:,4]);

# %% [markdown]
# ### 3 d plotting with plotly

# %%
tracks_with_feats_num_c.head(1)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.418   0.668    6   -11.297     0        0.082      0.000143
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.00113     0.173    0.379  162.663       167933               4
#
#    cluster
# 0      176

# %%
markersize= tracks_with_feats_num_c['tempo']
markercolour= tracks_with_feats_num_c['cluster']

fig1=go.Scatter3d(x=tracks_with_feats_num_c['danceability'],
                  y=tracks_with_feats_num_c['acousticness'],
                  z=tracks_with_feats_num_c['energy'],
                 marker=dict (size=markersize,
                              color=markercolour,
                              opacity=0.9,
                              colorscale='Blues'),
                 line=dict (width=0.2),
                 mode='markers')
#make layout 
mylayout=go.Layout(scene=dict(xaxis=dict(title="danceability"),
                              yaxis=dict(title='acousticness'),
                              zaxis=dict(title='energy')))

# %%
plotly.offline.plot({"data":[fig1],
                    "layout":mylayout},
                   auto_open=True,
                   filename=("5Dplot.html"))
# Out:
# '5Dplot.html'

# %%
tracks_with_feats_num_c.to_csv('tracks_with_feats_num_c.csv')

# %%
tracks_c = tracks_with_feats_num_c

# %%
tracks_c
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.418   0.668    6   -11.297     0       0.0820      0.000143
# 1            0.473   0.918    9    -3.580     1       0.0566      0.014500
# 2            0.452   0.701    9    -9.534     1       0.0677      0.145000
# 3            0.436   0.710    9    -5.666     1       0.0350      0.011300
# 4            0.339   0.824    9    -9.522     1       0.0938      0.005210
# ...            ...     ...  ...       ...   ...          ...           ...
# 7519         0.427   0.867    7    -9.077     1       0.1280      0.005350
# 7520         0.425   0.808    9    -8.376     0       0.2210      0.005340
# 7521         0.527   0.789    9    -8.049     1       0.0694      0.014000
# 7522         0.354   0.711    4   -10.134     0       0.1490      0.000499
# 7523         0.455   0.975    2    -6.137     1       0.0822      0.000022
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.001130    0.1730    0.379  162.663       167933
# 1             0.002480    0.3270    0.586  137.606       290067
# 2             0.008170    0.2670    0.519   90.157       474560
# 3             0.008110    0.0767    0.735   92.887       255200
# 4             0.004320    0.0803    0.538  154.573       354240
# ...                ...       ...      ...      ...          ...
# 7519          0.000846    0.0785    0.560  170.256       320627
# 7520          0.179000    0.1750    0.369   92.257       216907
# 7521          0.013300    0.3810    0.452   86.137       260267
# 7522          0.000423    0.2450    0.518   84.268       239640
# 7523          0.041500    0.3090    0.294  128.377       450667
#
#       time_signature  cluster
# 0                  4      176
# 1                  4      181
# 2                  4       69
# 3                  4      141
# 4                  4       55
# ...              ...      ...
# 7519               4      130
# 7520               4       98
# 7521               4       73
# 7522               4      182
# 7523               4      116
#
# [7524 rows x 14 columns]

# %% [markdown]
# ## Scaling the data - before clustering
# + will it make a difference
# + we know clustering algorithms

# %%
from sklearn.preprocessing import StandardScaler

# %%
tracks_with_feats_df_scaled=StandardScaler().fit_transform(tracks_c)

# %%
tracks_with_feats_df_scaled.shape
# Out:
# (7524, 14)

# %%
tracks_with_feats_num_c.columns.to_list()
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature',
#  'cluster']

# %%
tracks_with_feats_df_2=pd.DataFrame(tracks_with_feats_num_c,columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature','cluster'])
tracks_with_feats_df_2
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.418   0.668    6   -11.297     0       0.0820      0.000143
# 1            0.473   0.918    9    -3.580     1       0.0566      0.014500
# 2            0.452   0.701    9    -9.534     1       0.0677      0.145000
# 3            0.436   0.710    9    -5.666     1       0.0350      0.011300
# 4            0.339   0.824    9    -9.522     1       0.0938      0.005210
# ...            ...     ...  ...       ...   ...          ...           ...
# 7519         0.427   0.867    7    -9.077     1       0.1280      0.005350
# 7520         0.425   0.808    9    -8.376     0       0.2210      0.005340
# 7521         0.527   0.789    9    -8.049     1       0.0694      0.014000
# 7522         0.354   0.711    4   -10.134     0       0.1490      0.000499
# 7523         0.455   0.975    2    -6.137     1       0.0822      0.000022
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.001130    0.1730    0.379  162.663       167933
# 1             0.002480    0.3270    0.586  137.606       290067
# 2             0.008170    0.2670    0.519   90.157       474560
# 3             0.008110    0.0767    0.735   92.887       255200
# 4             0.004320    0.0803    0.538  154.573       354240
# ...                ...       ...      ...      ...          ...
# 7519          0.000846    0.0785    0.560  170.256       320627
# 7520          0.179000    0.1750    0.369   92.257       216907
# 7521          0.013300    0.3810    0.452   86.137       260267
# 7522          0.000423    0.2450    0.518   84.268       239640
# 7523          0.041500    0.3090    0.294  128.377       450667
#
#       time_signature  cluster
# 0                  4      176
# 1                  4      181
# 2                  4       69
# 3                  4      141
# 4                  4       55
# ...              ...      ...
# 7519               4      130
# 7520               4       98
# 7521               4       73
# 7522               4      182
# 7523               4      116
#
# [7524 rows x 14 columns]

# %%
tracks_with_feats_df_2.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   7524.000000  7524.000000  7524.000000  7524.000000  7524.000000
# mean       0.418782     0.832270     5.371478    -6.559703     0.505981
# std        0.123464     0.160272     3.485309     3.105137     0.499997
# min        0.000000     0.006670     0.000000   -36.756000     0.000000
# 25%        0.330000     0.773000     2.000000    -8.066750     0.000000
# 50%        0.428000     0.887000     5.000000    -5.761000     1.000000
# 75%        0.502000     0.945000     9.000000    -4.374000     1.000000
# max        0.929000     0.999000    11.000000     0.878000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness     valence  \
# count  7524.000000   7524.000000       7524.000000  7524.000000  7524.00000
# mean      0.073742      0.048318          0.098352     0.224312     0.36664
# std       0.052462      0.137031          0.219908     0.176741     0.19856
# min       0.000000      0.000000          0.000000     0.015100     0.00000
# 25%       0.039600      0.000181          0.000018     0.101750     0.21300
# 50%       0.056900      0.001780          0.001080     0.159000     0.34000
# 75%       0.088100      0.019000          0.044575     0.311000     0.49700
# max       0.505000      0.994000          0.994000     0.993000     0.97800
#
#              tempo   duration_ms  time_signature      cluster
# count  7524.000000  7.524000e+03     7524.000000  7524.000000
# mean    126.637288  2.743800e+05        3.925970   100.065125
# std      28.975499  8.878315e+04        0.345835    55.718718
# min       0.000000  8.093000e+03        0.000000     0.000000
# 25%     104.004750  2.245435e+05        4.000000    55.000000
# 50%     125.435000  2.606470e+05        4.000000   100.000000
# 75%     145.359000  3.079730e+05        4.000000   148.000000
# max     211.270000  1.505453e+06        5.000000   199.000000

# %%
tracks_with_feats_df_2.hist(bins=15, figsize=(15,15));

# %% [markdown]
# ### Cluster after scaling

# %%
kmeans2=KMeans(n_clusters=200)

# %%
cluster_scaled2=kmeans.fit(tracks_with_feats_df_2)

# %%
cluster_scaled2.cluster_centers_
# Out:
# array([[3.79625000e-01, 6.91750000e-01, 3.50000000e+00, ...,
#         1.15108375e+05, 3.62500000e+00, 1.47000000e+02],
#        [4.20235294e-01, 7.84023529e-01, 5.51764706e+00, ...,
#         2.87201318e+05, 3.96470588e+00, 6.00000000e+01],
#        [3.31000000e-01, 8.29222222e-01, 5.33333333e+00, ...,
#         4.40289722e+05, 3.88888889e+00, 1.14388889e+02],
#        ...,
#        [3.91666667e-01, 8.50555556e-01, 5.55555556e+00, ...,
#         1.59813111e+05, 4.00000000e+00, 1.42500000e+02],
#        [4.20882353e-01, 8.41313725e-01, 4.74509804e+00, ...,
#         2.04113765e+05, 3.98039216e+00, 6.46666667e+01],
#        [3.57700000e-01, 7.85700000e-01, 6.30000000e+00, ...,
#         5.07121900e+05, 3.90000000e+00, 5.70000000e+01]])

# %%
cluster_scaled2.labels_
# Out:
# array([ 29, 128, 167, ..., 143,  64,  55])

# %%
tracks_with_feats_df_2_c=tracks_with_feats_df_2.copy()
tracks_with_feats_df_2_c['cluster2']=cluster_scaled2.labels_

# %%
tracks_with_feats_df_2_c.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.418   0.668    6   -11.297     0       0.0820      0.000143
# 1         0.473   0.918    9    -3.580     1       0.0566      0.014500
# 2         0.452   0.701    9    -9.534     1       0.0677      0.145000
# 3         0.436   0.710    9    -5.666     1       0.0350      0.011300
# 4         0.339   0.824    9    -9.522     1       0.0938      0.005210
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0           0.00113    0.1730    0.379  162.663       167933               4
# 1           0.00248    0.3270    0.586  137.606       290067               4
# 2           0.00817    0.2670    0.519   90.157       474560               4
# 3           0.00811    0.0767    0.735   92.887       255200               4
# 4           0.00432    0.0803    0.538  154.573       354240               4
#
#    cluster  cluster2
# 0      176        29
# 1      181       128
# 2       69       167
# 3      141       115
# 4       55         5

# %%
tracks_with_feats_df_2_c['cluster2'].value_counts()
# Out:
# 164    107
# 14     103
# 41     102
# 115     99
# 99      98
#       ...
# 4        1
# 179      1
# 48       1
# 58       1
# 13       1
# Name: cluster2, Length: 200, dtype: int64

# %% [markdown]
# ## Finding Optimal K

# %%
kmeans.inertia_
# Out:
# 3359914012.729719

# %%
kmeans=KMeans(n_clusters=9)
kmeans.fit(tracks_with_feats_df_2_c)
print(kmeans.inertia_)
# Out:
# 2637379173894.242

# %%
K= range(2,30)
# whats the range of k you want to consider ?

# %%
#gathering the k inertia values 
inertia = []
for k in K:
    kmeans=KMeans(n_clusters=k,random_state=40)
    kmeans.fit(tracks_with_feats_df_2_c)
    inertia.append(kmeans.inertia_)

print(inertia)
# Out:
# [30224484828696.78, 18604131549782.824, 12456768929503.133, 8660268320751.115, 6105691519848.187, 4658549586212.235, 3513699997384.9, 2637471607668.319, 2049951915491.818, 1644098265354.616, 1392315691639.5852, 1177981145669.935, 996972583441.4745, 863757090752.849, 763565932117.6672, 685346761321.827, 628383004795.3265, 576292907557.3606, 518337232163.40564, 470858534766.1945, 423933015905.02826, 385330513097.7424, 350824679806.7554, 324454011545.6476, 299185824834.1399, 282871189407.3977, 263692222828.16162, 247407219097.82706]

# %%
# plot the results 
plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K),max(K)+1,1.0))
plt.title('elbow method, optimal k by inertia');

# %%
from sklearn.metrics import silhouette_score

# %%
K = range(2, 20)

silhouettes = []

for k in K: 
    kmeans=KMeans(n_clusters=k, random_state=40)
    kmeans.fit(tracks_with_feats_df_2_c)
    silhouettes.append(silhouette_score(tracks_with_feats_df_2_c, kmeans.predict(tracks_with_feats_df_2_c)))

# %%
plt.figure(figsize=(16,8))
plt.plot(K, silhouettes, 'bo-')
plt.xlabel('k (number of clusters)')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.ylabel('silhouette score')
# Out:
# Text(0, 0.5, 'silhouette score')

# %%
tracks_with_feats_df_2.info() #scaled data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7524 entries, 0 to 7523
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      7524 non-null   float64
#  1   energy            7524 non-null   float64
#  2   key               7524 non-null   int64
#  3   loudness          7524 non-null   float64
#  4   mode              7524 non-null   int64
#  5   speechiness       7524 non-null   float64
#  6   acousticness      7524 non-null   float64
#  7   instrumentalness  7524 non-null   float64
#  8   liveness          7524 non-null   float64
#  9   valence           7524 non-null   float64
#  10  tempo             7524 non-null   float64
#  11  duration_ms       7524 non-null   int64
#  12  time_signature    7524 non-null   int64
#  13  cluster           7524 non-null   int32
# dtypes: float64(9), int32(1), int64(4)
# memory usage: 852.3 KB
